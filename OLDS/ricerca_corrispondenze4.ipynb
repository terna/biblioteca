# %%
# ===========================
# Biblio longform -> enrich (OPAC SBN -> Open Library -> LoC -> Internet Archive)
# TWO-PASS MODE:
#   Pass 1: standard cascade, strict threshold
#   Pass 2: only NOT_FOUND, more query variants + relaxed threshold
# Output: LONG enriched + WIDE enriched
# Key requirement: ext_url ALWAYS "human record page" (incl. OPAC SBN)
# ===========================

import os, re, json, time
from difflib import SequenceMatcher
from urllib.parse import quote_plus

import pandas as pd
import requests

# ---------------------------
# CONFIG
# ---------------------------
INPUT_CSV     = "biblio_longform_all_records.csv"
OUTPUT_LONG   = "biblio_longform_all_records_enriched.csv"
OUTPUT_WIDE   = "biblio_wide_records_enriched.csv"
PROGRESS_JSON = "biblio_enrich_progress.json"

TOPK_PER_SOURCE = 12
TIMEOUT = 30
SLEEP_BETWEEN_CALLS = 0.25

MIN_SCORE_KEEP = 0.12
MIN_SCORE_FOUND_1ST = 0.40     # first pass acceptance
MIN_SCORE_FOUND_2ND = 0.28     # second pass acceptance (ONLY for NOT_FOUND)

ALLOW_AUTHOR_ONLY_QUERIES = True
DEBUG_SBN = False

CONTACT_EMAIL = "pietro.terna@unito.it"
UA = f"biblio-enricher/5.0 (Jupyter; contact: {CONTACT_EMAIL})"

STANDARD_FIELDS = [
    "ext_source","ext_match_score","ext_title","ext_author","ext_year",
    "ext_publisher","ext_place","ext_language","ext_physical_desc",
    "ext_identifiers","ext_notes","ext_url"
]

SESSION = requests.Session()
SESSION.headers.update({"User-Agent": UA})

def _sleep():
    time.sleep(SLEEP_BETWEEN_CALLS)

# ---------------------------
# Helpers
# ---------------------------
def norm(s: str) -> str:
    if s is None:
        return ""
    s = str(s).strip().lower()
    s = re.sub(r"\s+", " ", s)
    s = re.sub(r"[“”\"'’`]", "", s)
    s = re.sub(r"[^0-9a-zàèéìòùçäëïöüßñ \-:/]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

def sim(a: str, b: str) -> float:
    a, b = norm(a), norm(b)
    if not a or not b:
        return 0.0
    return SequenceMatcher(None, a, b).ratio()

def extract_year(s: str):
    if not s:
        return None
    m = re.search(r"(1[5-9]\d{2}|20\d{2})", str(s))
    return int(m.group(1)) if m else None

def normalize_year_from_data_pub(data_pub: str):
    return extract_year(data_pub)

def parse_series(collezion: str):
    if not collezion:
        return ("", "")
    s = str(collezion).strip()
    m = re.search(r"\bN\.?\s*(\d+)\b", s, flags=re.IGNORECASE)
    if m:
        no = m.group(1)
        series = re.sub(r"\bN\.?\s*\d+\b", "", s, flags=re.IGNORECASE).strip(" ,;-")
        return (series.strip(), no)
    return (s, "")

def pack_identifiers(d: dict) -> str:
    return json.dumps(d or {}, ensure_ascii=False)

def safe_list(v):
    if v is None:
        return []
    if isinstance(v, list):
        return v
    return [v]

def first_nonempty(vals):
    for v in vals:
        if v is None:
            continue
        s = str(v).strip()
        if s and s.lower() != "nan":
            return s
    return ""

def load_progress():
    if os.path.exists(PROGRESS_JSON):
        with open(PROGRESS_JSON, "r", encoding="utf-8") as f:
            return json.load(f)
    return {"done_n_scheda": [], "last_book_number": 0}

def save_progress(prog):
    with open(PROGRESS_JSON, "w", encoding="utf-8") as f:
        json.dump(prog, f, ensure_ascii=False, indent=2)

# ---------------------------
# OPAC SBN "page url"
# ---------------------------
def sbn_bid_to_page_url(bid: str) -> str:
    if not isinstance(bid, str) or not bid.strip():
        return ""
    bid = bid.strip()
    m = re.match(r"^IT\\ICCU\\([A-Za-z0-9]{3})\\([0-9]{1,10})$", bid)
    if m:
        polo = m.group(1).upper()
        num = m.group(2).zfill(7)
        return f"https://opac.sbn.it/bid/{polo}{num}"
    return f"https://opac.sbn.it/bid/{bid.replace('\\\\','')}"

# ---------------------------
# SBN helpers
# ---------------------------
def sbn_clean_query(s: str) -> str:
    s = (s or "")
    s = re.sub(r"[\"'’`]", "", s)
    s = re.sub(r"[,.;:()\\[\\]{}<>|]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

def sbn_clean_author(a: str) -> str:
    # remove common honorifics/titles and trailing qualifiers
    a = (a or "")
    a = re.sub(r"\b(card\.?|arciv\.?|mons\.?|rev\.?|s\.j\.?|o\.p\.?)\b", " ", a, flags=re.IGNORECASE)
    a = re.sub(r"\s+", " ", a).strip()
    return a

def sbn_clean_title(t: str) -> str:
    t = (t or "")
    t = re.sub(r"\s*/\s*.*$", "", t)  # drop anything after " / " (often author)
    t = re.sub(r"\s*:\s*.*$", "", t)  # optionally shorten after ":" for very long titles
    t = re.sub(r"\s+", " ", t).strip()
    return t

def sbn_extract_hits(js):
    if not isinstance(js, dict):
        return []
    for k in ["briefRecords", "records", "record", "results", "elenco", "items", "docs"]:
        v = js.get(k)
        if isinstance(v, list):
            return v
    for k in ["result", "response", "data"]:
        v = js.get(k)
        if isinstance(v, dict):
            for k2 in ["briefRecords", "records", "items", "docs", "results", "elenco"]:
                v2 = v.get(k2)
                if isinstance(v2, list):
                    return v2
    return []

def series_bonus(book, text):
    series = norm(book.get("series",""))
    s_no   = norm(book.get("series_no",""))
    t = norm(text)
    bonus = 0.0
    if series and series in t:
        bonus += 0.10
    if s_no and re.search(rf"\b{s_no}\b", t):
        bonus += 0.06
    return bonus

# ---------------------------
# Load input
# ---------------------------
df = pd.read_csv(INPUT_CSV)
need_cols = {"n_scheda","campo","valore"}
if not need_cols.issubset(df.columns):
    raise ValueError(f"CSV non nel formato atteso. Colonne trovate={list(df.columns)}; servono {sorted(need_cols)}")

df["n_scheda"] = df["n_scheda"].astype(int)
df["campo"] = df["campo"].astype(str)
df["valore"] = df["valore"].astype(str)

groups = list(df.groupby("n_scheda", sort=True))
n_books = len(groups)

def book_input_from_group(g: pd.DataFrame) -> dict:
    rec = {"n_scheda": int(g["n_scheda"].iloc[0])}

    def fv(field):
        vals = g.loc[g["campo"] == field, "valore"].tolist()
        return first_nonempty(vals)

    rec["autore"]    = fv("autore")
    rec["titolo"]    = fv("titolo")
    rec["editore"]   = fv("editore")
    rec["luogo_pub"] = fv("luogo_pub")
    rec["data_pub"]  = fv("data_pub")
    rec["cod_isbn"]  = fv("cod_isbn")
    rec["collezion"] = fv("collezion")

    rec["year"] = normalize_year_from_data_pub(rec["data_pub"]) or extract_year(rec["titolo"])
    series, series_no = parse_series(rec["collezion"])
    rec["series"] = series
    rec["series_no"] = series_no
    return rec

def build_queries_pass1(book: dict):
    titolo  = (book.get("titolo") or "").strip()
    autore  = (book.get("autore") or "").strip()
    editore = (book.get("editore") or "").strip()
    year    = book.get("year")
    series  = (book.get("series") or "").strip()
    s_no    = (book.get("series_no") or "").strip()

    queries = []
    if titolo:
        q1 = " ".join([x for x in [titolo, autore, str(year) if year else ""] if x]).strip()
        q2 = " ".join([x for x in [titolo, autore] if x]).strip()
        q3 = " ".join([x for x in [titolo, autore, editore, str(year) if year else ""] if x]).strip()
        for q in [q1, q2, q3]:
            if q and q not in queries:
                queries.append(q)
        return queries

    # no title
    qA = " ".join([x for x in [autore, series, s_no, editore, str(year) if year else ""] if x]).strip()
    qB = " ".join([x for x in [autore, series, s_no] if x]).strip()
    qC = " ".join([x for x in [autore, series] if x]).strip()
    qD = " ".join([x for x in [autore, str(year) if year else "", editore] if x]).strip()

    for q in [qA, qB, qC, qD]:
        if q and q not in queries:
            queries.append(q)

    if ALLOW_AUTHOR_ONLY_QUERIES and autore and autore not in queries:
        queries.append(autore)

    return queries

def build_queries_pass2(book: dict):
    """
    More aggressive variants (only used for NOT_FOUND).
    """
    titolo  = (book.get("titolo") or "").strip()
    autore  = (book.get("autore") or "").strip()
    editore = (book.get("editore") or "").strip()
    luogo   = (book.get("luogo_pub") or "").strip()
    year    = book.get("year")
    series  = (book.get("series") or "").strip()
    s_no    = (book.get("series_no") or "").strip()

    autore2 = sbn_clean_author(autore)
    titolo2 = sbn_clean_title(titolo)

    variants = []

    # title present: include cleaned title/author variants, and drop publisher/year variants too
    if titolo:
        base = [
            " ".join([x for x in [titolo, autore] if x]),
            " ".join([x for x in [titolo2, autore] if x]),
            " ".join([x for x in [titolo2, autore2] if x]),
            " ".join([x for x in [titolo2, autore2, str(year) if year else ""] if x]),
            " ".join([x for x in [titolo2, editore] if x]),
            " ".join([x for x in [titolo2, luogo] if x]),
        ]
        for q in base:
            q = q.strip()
            if q and q not in variants:
                variants.append(q)
        # author-only as last resort
        if ALLOW_AUTHOR_ONLY_QUERIES and autore2 and autore2 not in variants:
            variants.append(autore2)
        return variants

    # no title: lean on series / number / publisher / place
    base = [
        " ".join([x for x in [autore2, series, s_no] if x]),
        " ".join([x for x in [series, s_no, editore] if x]),
        " ".join([x for x in [autore2, editore, luogo] if x]),
        " ".join([x for x in [autore2, str(year) if year else "", editore] if x]),
        " ".join([x for x in [series, editore] if x]),
        " ".join([x for x in [autore2] if x]),
    ]
    for q in base:
        q = q.strip()
        if q and q not in variants:
            variants.append(q)
    return variants

# ---------------------------
# OPAC SBN API
# ---------------------------
def sbn_search_any(q: str, rows=TOPK_PER_SOURCE):
    url = f"https://opac.sbn.it/opacmobilegw/search.json?any={quote_plus(q)}&type=0&start=0&rows={rows}"
    r = SESSION.get(url, timeout=TIMEOUT)
    _sleep()
    r.raise_for_status()
    return r.json()

def sbn_search_isbn(isbn: str, rows=TOPK_PER_SOURCE):
    url = f"https://opac.sbn.it/opacmobilegw/search.json?isbn={quote_plus(isbn)}&start=0&rows={rows}"
    r = SESSION.get(url, timeout=TIMEOUT)
    _sleep()
    r.raise_for_status()
    return r.json()

def sbn_full(bid: str):
    url = f"https://opac.sbn.it/opacmobilegw/full.json?bid={quote_plus(bid)}"
    r = SESSION.get(url, timeout=TIMEOUT)
    _sleep()
    r.raise_for_status()
    return r.json()

def _score_sbn_hits(book, hits):
    titolo_in = (book.get("titolo") or "").strip()
    autore_in = sbn_clean_author(book.get("autore") or "").strip()
    year_in   = book.get("year")

    cands = []
    for h in (hits or [])[:TOPK_PER_SOURCE]:
        title = h.get("titolo") or ""
        auth  = h.get("autorePrincipale") or ""
        pub   = h.get("pubblicazione") or ""
        bid   = h.get("codiceIdentificativo") or ""
        by = extract_year(pub)

        if titolo_in:
            score = 0.70 * sim(titolo_in, title) + 0.30 * sim(autore_in, auth)
        else:
            score = 0.85 * sim(autore_in, auth) + 0.15 * (0.2 if title else 0.0)

        score += series_bonus(book, f"{title} {pub}")

        if year_in and by and abs(year_in - by) <= 1:
            score += 0.06

        if score >= MIN_SCORE_KEEP:
            cands.append({"source":"OPAC SBN","score":score,"title":title,"author":auth,"pub":pub,"bid":bid,"raw":h})

    cands.sort(key=lambda x: x["score"], reverse=True)

    for c in cands[:2]:
        if c.get("bid"):
            try:
                c["full"] = sbn_full(c["bid"])
            except Exception:
                c["full"] = None
    return cands

def sbn_candidates(book: dict, pass_no: int):
    isbn = (book.get("cod_isbn") or "").strip()

    queries = build_queries_pass1(book) if pass_no == 1 else build_queries_pass2(book)

    # ISBN-first in both passes
    if isbn:
        try:
            js = sbn_search_isbn(isbn)
            hits = sbn_extract_hits(js)
            if DEBUG_SBN:
                print(f"   SBN[isbn] numFound={js.get('numFound')} hits={len(hits)}")
            c = _score_sbn_hits(book, hits)
            if c:
                return c
        except Exception:
            pass

    # any= variants
    for q in queries:
        if not q:
            continue
        for qv in [q, sbn_clean_query(q)]:
            if not qv:
                continue
            try:
                js = sbn_search_any(qv)
                hits = sbn_extract_hits(js)
                if DEBUG_SBN:
                    print(f"   SBN[any] hits={len(hits)} q='{qv[:70]}'")
                c = _score_sbn_hits(book, hits)
                if c:
                    return c
            except Exception:
                continue

    return []

# ---------------------------
# Open Library
# ---------------------------
def ol_search_q(q: str, rows=TOPK_PER_SOURCE):
    params = {"q": q, "limit": rows}
    r = SESSION.get("https://openlibrary.org/search.json", params=params, timeout=TIMEOUT)
    _sleep()
    r.raise_for_status()
    return r.json()

def ol_candidates(book: dict, pass_no: int):
    isbn = (book.get("cod_isbn") or "").strip()
    queries = []
    if isbn:
        queries.append(f"isbn:{isbn}")
    queries.extend(build_queries_pass1(book) if pass_no == 1 else build_queries_pass2(book))

    titolo_in = (book.get("titolo") or "").strip()
    autore_in = sbn_clean_author(book.get("autore") or "").strip()
    year_in   = book.get("year")

    for q in queries:
        if not q:
            continue
        try:
            js = ol_search_q(q)
        except Exception:
            continue

        docs = js.get("docs", [])[:TOPK_PER_SOURCE]
        cands = []
        for d in docs:
            title = d.get("title") or ""
            auth  = (d.get("author_name") or [""])[0]
            year  = d.get("first_publish_year")
            pub   = (d.get("publisher") or [""])[0] if isinstance(d.get("publisher"), list) else (d.get("publisher") or "")
            place = (d.get("publish_place") or [""])[0] if isinstance(d.get("publish_place"), list) else (d.get("publish_place") or "")
            lang  = (d.get("language") or [""])[0] if isinstance(d.get("language"), list) else (d.get("language") or "")
            key   = d.get("key","")

            if titolo_in:
                score = 0.70 * sim(titolo_in, title) + 0.30 * sim(autore_in, auth)
            else:
                score = 0.85 * sim(autore_in, auth) + 0.15 * (0.2 if title else 0.0)

            score += series_bonus(book, f"{title} {pub} {place}")

            if year_in and year and abs(year_in - int(year)) <= 1:
                score += 0.05

            if score >= MIN_SCORE_KEEP:
                cands.append({"source":"Open Library","score":score,"title":title,"author":auth,"year":year,
                              "publisher":pub,"place":place,"language":lang,"key":key,"raw":d})

        cands.sort(key=lambda x: x["score"], reverse=True)
        if cands:
            return cands

    return []

# ---------------------------
# Library of Congress
# ---------------------------
def loc_search(q: str, rows=TOPK_PER_SOURCE):
    params = {"fo":"json", "q": q, "c": rows}
    r = SESSION.get("https://www.loc.gov/books/", params=params, timeout=TIMEOUT)
    _sleep()
    r.raise_for_status()
    return r.json()

def loc_candidates(book: dict, pass_no: int):
    queries = build_queries_pass1(book) if pass_no == 1 else build_queries_pass2(book)
    titolo_in = (book.get("titolo") or "").strip()
    autore_in = sbn_clean_author(book.get("autore") or "").strip()
    year_in   = book.get("year")

    for q in queries:
        if not q:
            continue
        try:
            js = loc_search(q)
        except Exception:
            continue

        results = js.get("results", [])[:TOPK_PER_SOURCE]
        cands = []
        for it in results:
            title = it.get("title") or ""
            auth_list = it.get("contributor") or it.get("creator") or []
            auth = auth_list[0] if isinstance(auth_list, list) and auth_list else ""
            date = it.get("date") or ""
            year = extract_year(date)
            loc_id = it.get("id") or ""

            if titolo_in:
                score = 0.70 * sim(titolo_in, title) + 0.30 * sim(autore_in, auth)
            else:
                score = 0.85 * sim(autore_in, auth) + 0.15 * (0.2 if title else 0.0)

            score += series_bonus(book, f"{title} {date}")

            if year_in and year and abs(year_in - year) <= 1:
                score += 0.05

            if score >= MIN_SCORE_KEEP:
                cands.append({"source":"Library of Congress","score":score,"title":title,"author":auth,"date":date,"id":loc_id,"raw":it})

        cands.sort(key=lambda x: x["score"], reverse=True)
        if cands:
            return cands

    return []

# ---------------------------
# Internet Archive
# ---------------------------
def ia_advanced_search(title: str, author: str, q_extra: str = "", rows=TOPK_PER_SOURCE):
    q = []
    if title:
        q.append(f'title:("{title}")')
    if author:
        q.append(f'creator:("{author}")')
    if q_extra:
        q.append(q_extra)
    q.append('(mediatype:texts OR collection:opensource_texts)')
    query = " AND ".join([x for x in q if x])

    params = {
        "q": query,
        "fl[]": ["identifier", "title", "creator", "date", "publisher", "language"],
        "rows": rows,
        "page": 1,
        "output": "json"
    }
    r = SESSION.get("https://archive.org/advancedsearch.php", params=params, timeout=TIMEOUT)
    _sleep()
    r.raise_for_status()
    return r.json()

def ia_metadata(identifier: str):
    r = SESSION.get(f"https://archive.org/metadata/{identifier}", timeout=TIMEOUT)
    _sleep()
    r.raise_for_status()
    return r.json()

def ia_candidates(book: dict, pass_no: int):
    titolo_in = (book.get("titolo") or "").strip()
    autore_in = sbn_clean_author(book.get("autore") or "").strip()
    year_in   = book.get("year")
    queries = build_queries_pass1(book) if pass_no == 1 else build_queries_pass2(book)

    cands_all = []
    for q in queries[:5 if pass_no==2 else 3]:
        try:
            js = ia_advanced_search(titolo_in if titolo_in else "", autore_in if autore_in else "", q_extra=q)
        except Exception:
            continue

        docs = (js.get("response", {}).get("docs", []) or [])[:TOPK_PER_SOURCE]
        for d in docs:
            title = d.get("title") or ""
            creator = d.get("creator")
            auth = creator[0] if isinstance(creator, list) and creator else (creator or "")
            year = extract_year(d.get("date"))
            ident = d.get("identifier")

            if titolo_in:
                score = 0.70 * sim(titolo_in, title) + 0.30 * sim(autore_in, auth)
            else:
                score = 0.85 * sim(autore_in, auth) + 0.15 * (0.2 if title else 0.0)

            score += series_bonus(book, f"{title} {d.get('publisher','')}")

            if year_in and year and abs(year_in - year) <= 1:
                score += 0.05

            if score >= MIN_SCORE_KEEP:
                cands_all.append({"source":"Internet Archive","score":score,"title":title,"author":auth,"year":year,
                                  "identifier":ident,"raw":d})

        if cands_all:
            break

    cands_all.sort(key=lambda x: x["score"], reverse=True)

    if cands_all and cands_all[0].get("identifier"):
        try:
            cands_all[0]["full"] = ia_metadata(cands_all[0]["identifier"])
        except Exception:
            cands_all[0]["full"] = None

    return cands_all

# ---------------------------
# Map to ext_* (ext_url always human page)
# ---------------------------
def from_sbn(best: dict) -> dict:
    full = best.get("full") or {}
    bid = best.get("bid","")
    return {
        "ext_source": "OPAC SBN",
        "ext_match_score": f"{best.get('score',0):.3f}",
        "ext_title": full.get("titolo") or best.get("title") or "",
        "ext_author": full.get("autorePrincipale") or best.get("author") or "",
        "ext_year": str(extract_year(full.get("pubblicazione")) or extract_year(best.get("pub")) or "" or ""),
        "ext_publisher": "",
        "ext_place": "",
        "ext_language": full.get("linguaPubblicazione") or "",
        "ext_physical_desc": full.get("descrizioneFisica") or "",
        "ext_identifiers": pack_identifiers({"bid": bid}),
        "ext_notes": " | ".join(safe_list(full.get("note"))) if full.get("note") else "",
        "ext_url": sbn_bid_to_page_url(bid)
    }

def from_ol(best: dict) -> dict:
    d = best.get("raw") or {}
    identifiers = {}
    for k in ["isbn", "oclc", "lccn"]:
        if k in d and d[k]:
            identifiers[k] = d[k][:10] if isinstance(d[k], list) else d[k]
    key = best.get("key","") or d.get("key","")
    return {
        "ext_source": "Open Library",
        "ext_match_score": f"{best.get('score',0):.3f}",
        "ext_title": best.get("title") or "",
        "ext_author": best.get("author") or "",
        "ext_year": str(best.get("year") or ""),
        "ext_publisher": best.get("publisher") or "",
        "ext_place": best.get("place") or "",
        "ext_language": best.get("language") or "",
        "ext_physical_desc": "",
        "ext_identifiers": pack_identifiers(identifiers),
        "ext_notes": "",
        "ext_url": f"https://openlibrary.org{key}" if key else ""
    }

def from_loc(best: dict) -> dict:
    return {
        "ext_source": "Library of Congress",
        "ext_match_score": f"{best.get('score',0):.3f}",
        "ext_title": best.get("title") or "",
        "ext_author": best.get("author") or "",
        "ext_year": str(extract_year(best.get("date") or "") or ""),
        "ext_publisher": "",
        "ext_place": "",
        "ext_language": "",
        "ext_physical_desc": "",
        "ext_identifiers": pack_identifiers({"loc_id": best.get("id")}),
        "ext_notes": "",
        "ext_url": best.get("id") or ""
    }

def from_ia(best: dict) -> dict:
    full = best.get("full") or {}
    md = full.get("metadata") or {}

    def md1(k):
        v = md.get(k, "")
        if isinstance(v, list):
            return v[0] if v else ""
        return v or ""

    ident = best.get("identifier") or ""
    return {
        "ext_source": "Internet Archive",
        "ext_match_score": f"{best.get('score',0):.3f}",
        "ext_title": md1("title") or best.get("title") or "",
        "ext_author": md1("creator") or best.get("author") or "",
        "ext_year": str(extract_year(md1("date")) or best.get("year") or ""),
        "ext_publisher": md1("publisher"),
        "ext_place": md1("publishplace"),
        "ext_language": md1("language"),
        "ext_physical_desc": md1("description"),
        "ext_identifiers": pack_identifiers({"identifier": ident}),
        "ext_notes": md1("notes"),
        "ext_url": f"https://archive.org/details/{ident}" if ident else ""
    }

def choose_best_candidate(book: dict, pass_no: int):
    threshold = MIN_SCORE_FOUND_1ST if pass_no == 1 else MIN_SCORE_FOUND_2ND

    sbn = sbn_candidates(book, pass_no)
    if sbn and sbn[0]["score"] >= threshold:
        return sbn[0], from_sbn(sbn[0])

    ol = ol_candidates(book, pass_no)
    if ol and ol[0]["score"] >= threshold:
        return ol[0], from_ol(ol[0])

    loc = loc_candidates(book, pass_no)
    if loc and loc[0]["score"] >= threshold:
        return loc[0], from_loc(loc[0])

    ia = ia_candidates(book, pass_no)
    if ia and ia[0]["score"] >= threshold:
        return ia[0], from_ia(ia[0])

    return None, {
        "ext_source":"NOT_FOUND","ext_match_score":"0.000",
        "ext_title":"","ext_author":"","ext_year":"",
        "ext_publisher":"","ext_place":"","ext_language":"",
        "ext_physical_desc":"","ext_identifiers":pack_identifiers({}),
        "ext_notes":"","ext_url":""
    }

# ---------------------------
# RUN PASS 1 (resumable)
# ---------------------------
prog = load_progress()
done = set(int(x) for x in prog.get("done_n_scheda", []))

if os.path.exists(OUTPUT_LONG):
    out_df = pd.read_csv(OUTPUT_LONG)
    out_df["n_scheda"] = out_df["n_scheda"].astype(int)
    out_df["campo"] = out_df["campo"].astype(str)
    out_df["valore"] = out_df["valore"].astype(str)
else:
    out_df = df.copy()

already_ext = set()
mask_ext = out_df["campo"].astype(str).str.startswith("ext_")
for r in out_df.loc[mask_ext, ["n_scheda","campo"]].itertuples(index=False):
    already_ext.add((int(r.n_scheda), str(r.campo)))

added_rows = []

found_count = 0
notfound_count = 0
found_by_source = {"OPAC SBN": 0, "Open Library": 0, "Library of Congress": 0, "Internet Archive": 0}

for book_number, (n_scheda, g) in enumerate(groups, start=1):
    print(f"[PASS1 {book_number}/{n_books}] n_scheda={n_scheda}")
    if int(n_scheda) in done:
        continue

    book = book_input_from_group(g)
    _, ext = choose_best_candidate(book, pass_no=1)
    src = ext.get("ext_source")

    if src != "NOT_FOUND":
        found_count += 1
        if src in found_by_source:
            found_by_source[src] += 1
    else:
        notfound_count += 1

    for k in STANDARD_FIELDS:
        key = (int(n_scheda), k)
        if key in already_ext:
            continue
        added_rows.append({"n_scheda": int(n_scheda), "campo": k, "valore": ext.get(k,"")})
        already_ext.add(key)

    done.add(int(n_scheda))
    prog["done_n_scheda"] = sorted(done)
    prog["last_book_number"] = book_number
    save_progress(prog)

    if book_number % 10 == 0:
        if added_rows:
            out_df = pd.concat([out_df, pd.DataFrame(added_rows)], ignore_index=True)
            added_rows = []
        out_df.to_csv(OUTPUT_LONG, index=False)
        print(
            f"Checkpoint PASS1: {OUTPUT_LONG} | "
            f"found={found_count} not_found={notfound_count} | "
            f"SBN={found_by_source['OPAC SBN']} "
            f"OL={found_by_source['Open Library']} "
            f"LoC={found_by_source['Library of Congress']} "
            f"IA={found_by_source['Internet Archive']}"
        )

if added_rows:
    out_df = pd.concat([out_df, pd.DataFrame(added_rows)], ignore_index=True)
out_df.to_csv(OUTPUT_LONG, index=False)

print(
    f"PASS1 completed. LONG: {OUTPUT_LONG} | "
    f"found={found_count} not_found={notfound_count} | "
    f"SBN={found_by_source['OPAC SBN']} "
    f"OL={found_by_source['Open Library']} "
    f"LoC={found_by_source['Library of Congress']} "
    f"IA={found_by_source['Internet Archive']}"
)

# ---------------------------
# PASS 2: ONLY NOT_FOUND (overwrite ext_* for those)
# ---------------------------
# Identify NOT_FOUND from the CURRENT long
df_ext = out_df[out_df["campo"]=="ext_source"][["n_scheda","valore"]].copy()
df_ext["n_scheda"] = df_ext["n_scheda"].astype(int)
not_found_ids = set(df_ext.loc[df_ext["valore"]=="NOT_FOUND", "n_scheda"].tolist())

print(f"PASS2 starting: NOT_FOUND records = {len(not_found_ids)}")

# Build a quick lookup from original input groups
group_map = {int(n): g for (n, g) in groups}

# Remove existing ext_* rows for NOT_FOUND (so we can rewrite them cleanly)
mask_drop = out_df["n_scheda"].isin(list(not_found_ids)) & out_df["campo"].astype(str).str.startswith("ext_")
out_df = out_df.loc[~mask_drop].copy()

# Rebuild already_ext after drop
already_ext = set()
mask_ext = out_df["campo"].astype(str).str.startswith("ext_")
for r in out_df.loc[mask_ext, ["n_scheda","campo"]].itertuples(index=False):
    already_ext.add((int(r.n_scheda), str(r.campo)))

added_rows = []

pass2_found = 0
pass2_by_source = {"OPAC SBN": 0, "Open Library": 0, "Library of Congress": 0, "Internet Archive": 0}
pass2_still_not_found = 0

for idx, n_scheda in enumerate(sorted(not_found_ids), start=1):
    g = group_map.get(int(n_scheda))
    if g is None:
        continue
    print(f"[PASS2 {idx}/{len(not_found_ids)}] n_scheda={n_scheda}")

    book = book_input_from_group(g)
    _, ext = choose_best_candidate(book, pass_no=2)
    src = ext.get("ext_source")

    if src != "NOT_FOUND":
        pass2_found += 1
        if src in pass2_by_source:
            pass2_by_source[src] += 1
    else:
        pass2_still_not_found += 1

    for k in STANDARD_FIELDS:
        key = (int(n_scheda), k)
        if key in already_ext:
            continue
        added_rows.append({"n_scheda": int(n_scheda), "campo": k, "valore": ext.get(k,"")})
        already_ext.add(key)

    if idx % 10 == 0:
        if added_rows:
            out_df = pd.concat([out_df, pd.DataFrame(added_rows)], ignore_index=True)
            added_rows = []
        out_df.to_csv(OUTPUT_LONG, index=False)
        print(
            f"Checkpoint PASS2: {OUTPUT_LONG} | "
            f"pass2_found={pass2_found} pass2_still_not_found={pass2_still_not_found} | "
            f"SBN={pass2_by_source['OPAC SBN']} "
            f"OL={pass2_by_source['Open Library']} "
            f"LoC={pass2_by_source['Library of Congress']} "
            f"IA={pass2_by_source['Internet Archive']}"
        )

if added_rows:
    out_df = pd.concat([out_df, pd.DataFrame(added_rows)], ignore_index=True)

out_df.to_csv(OUTPUT_LONG, index=False)

print(
    f"PASS2 completed. LONG: {OUTPUT_LONG} | "
    f"pass2_found={pass2_found} pass2_still_not_found={pass2_still_not_found} | "
    f"SBN={pass2_by_source['OPAC SBN']} "
    f"OL={pass2_by_source['Open Library']} "
    f"LoC={pass2_by_source['Library of Congress']} "
    f"IA={pass2_by_source['Internet Archive']}"
)

# ---------------------------
# LONG -> WIDE
# ---------------------------
df_long = out_df.copy()
df_long["valore"] = df_long["valore"].fillna("").astype(str)
df_long.loc[df_long["campo"] == "n_scheda", "campo"] = "n_scheda_field"

agg = (df_long
       .groupby(["n_scheda","campo"])["valore"]
       .agg(lambda s: " | ".join([v.strip() for v in s if isinstance(v,str) and v.strip()]))
       .reset_index())

df_wide = agg.pivot(index="n_scheda", columns="campo", values="valore").reset_index()

front = ["n_scheda","titolo","autore","data_pub","luogo_pub","editore","collezion",
         "ext_source","ext_match_score","ext_title","ext_author","ext_year","ext_url","ext_identifiers","n_scheda_field"]
cols = [c for c in front if c in df_wide.columns] + [c for c in df_wide.columns if c not in front]
df_wide = df_wide[cols]

df_wide.to_csv(OUTPUT_WIDE, index=False)
print(f"WIDE creato: {OUTPUT_WIDE} | righe={len(df_wide)} colonne={len(df_wide.columns)}")
# Out:
# [PASS1 1/1000] n_scheda=41186
# [PASS1 2/1000] n_scheda=41187
# [PASS1 3/1000] n_scheda=41188
# [PASS1 4/1000] n_scheda=41189
# [PASS1 5/1000] n_scheda=41190
# [PASS1 6/1000] n_scheda=41191
# [PASS1 7/1000] n_scheda=41192
# [PASS1 8/1000] n_scheda=41193
# [PASS1 9/1000] n_scheda=41194
# [PASS1 10/1000] n_scheda=41195
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=7 not_found=3 | SBN=6 OL=1 LoC=0 IA=0
# [PASS1 11/1000] n_scheda=41196
# [PASS1 12/1000] n_scheda=41197
# [PASS1 13/1000] n_scheda=41198
# [PASS1 14/1000] n_scheda=41199
# [PASS1 15/1000] n_scheda=41200
# [PASS1 16/1000] n_scheda=41201
# [PASS1 17/1000] n_scheda=41202
# [PASS1 18/1000] n_scheda=41203
# [PASS1 19/1000] n_scheda=41204
# [PASS1 20/1000] n_scheda=41205
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=17 not_found=3 | SBN=13 OL=4 LoC=0 IA=0
# [PASS1 21/1000] n_scheda=41206
# [PASS1 22/1000] n_scheda=41207
# [PASS1 23/1000] n_scheda=41208
# [PASS1 24/1000] n_scheda=41209
# [PASS1 25/1000] n_scheda=41210
# [PASS1 26/1000] n_scheda=41211
# [PASS1 27/1000] n_scheda=41212
# [PASS1 28/1000] n_scheda=41213
# [PASS1 29/1000] n_scheda=41214
# [PASS1 30/1000] n_scheda=41215
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=26 not_found=4 | SBN=18 OL=8 LoC=0 IA=0
# [PASS1 31/1000] n_scheda=41216
# [PASS1 32/1000] n_scheda=41217
# [PASS1 33/1000] n_scheda=41218
# [PASS1 34/1000] n_scheda=41219
# [PASS1 35/1000] n_scheda=41220
# [PASS1 36/1000] n_scheda=41221
# [PASS1 37/1000] n_scheda=41222
# [PASS1 38/1000] n_scheda=41223
# [PASS1 39/1000] n_scheda=41224
# [PASS1 40/1000] n_scheda=41225
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=36 not_found=4 | SBN=28 OL=8 LoC=0 IA=0
# [PASS1 41/1000] n_scheda=41226
# [PASS1 42/1000] n_scheda=41227
# [PASS1 43/1000] n_scheda=41228
# [PASS1 44/1000] n_scheda=41229
# [PASS1 45/1000] n_scheda=41230
# [PASS1 46/1000] n_scheda=41231
# [PASS1 47/1000] n_scheda=41232
# [PASS1 48/1000] n_scheda=41233
# [PASS1 49/1000] n_scheda=41234
# [PASS1 50/1000] n_scheda=41235
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=46 not_found=4 | SBN=38 OL=8 LoC=0 IA=0
# [PASS1 51/1000] n_scheda=41236
# [PASS1 52/1000] n_scheda=41237
# [PASS1 53/1000] n_scheda=41238
# [PASS1 54/1000] n_scheda=41239
# [PASS1 55/1000] n_scheda=41240
# [PASS1 56/1000] n_scheda=41241
# [PASS1 57/1000] n_scheda=41242
# [PASS1 58/1000] n_scheda=41243
# [PASS1 59/1000] n_scheda=41244
# [PASS1 60/1000] n_scheda=41245
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=56 not_found=4 | SBN=46 OL=10 LoC=0 IA=0
# [PASS1 61/1000] n_scheda=41246
# [PASS1 62/1000] n_scheda=41247
# [PASS1 63/1000] n_scheda=41248
# [PASS1 64/1000] n_scheda=41249
# [PASS1 65/1000] n_scheda=41250
# [PASS1 66/1000] n_scheda=41251
# [PASS1 67/1000] n_scheda=41252
# [PASS1 68/1000] n_scheda=41253
# [PASS1 69/1000] n_scheda=41254
# [PASS1 70/1000] n_scheda=41255
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=65 not_found=5 | SBN=53 OL=12 LoC=0 IA=0
# [PASS1 71/1000] n_scheda=41256
# [PASS1 72/1000] n_scheda=41257
# [PASS1 73/1000] n_scheda=41258
# [PASS1 74/1000] n_scheda=41259
# [PASS1 75/1000] n_scheda=41260
# [PASS1 76/1000] n_scheda=41261
# [PASS1 77/1000] n_scheda=41262
# [PASS1 78/1000] n_scheda=41263
# [PASS1 79/1000] n_scheda=41264
# [PASS1 80/1000] n_scheda=41265
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=75 not_found=5 | SBN=63 OL=12 LoC=0 IA=0
# [PASS1 81/1000] n_scheda=41266
# [PASS1 82/1000] n_scheda=41267
# [PASS1 83/1000] n_scheda=41268
# [PASS1 84/1000] n_scheda=41269
# [PASS1 85/1000] n_scheda=41270
# [PASS1 86/1000] n_scheda=41271
# [PASS1 87/1000] n_scheda=41272
# [PASS1 88/1000] n_scheda=41273
# [PASS1 89/1000] n_scheda=41274
# [PASS1 90/1000] n_scheda=41275
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=85 not_found=5 | SBN=73 OL=12 LoC=0 IA=0
# [PASS1 91/1000] n_scheda=41276
# [PASS1 92/1000] n_scheda=41277
# [PASS1 93/1000] n_scheda=41278
# [PASS1 94/1000] n_scheda=41279
# [PASS1 95/1000] n_scheda=41280
# [PASS1 96/1000] n_scheda=41281
# [PASS1 97/1000] n_scheda=41282
# [PASS1 98/1000] n_scheda=41283
# [PASS1 99/1000] n_scheda=41284
# [PASS1 100/1000] n_scheda=41285
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=95 not_found=5 | SBN=83 OL=12 LoC=0 IA=0
# [PASS1 101/1000] n_scheda=41286
# [PASS1 102/1000] n_scheda=41287
# [PASS1 103/1000] n_scheda=41288
# [PASS1 104/1000] n_scheda=41289
# [PASS1 105/1000] n_scheda=41290
# [PASS1 106/1000] n_scheda=41291
# [PASS1 107/1000] n_scheda=41292
# [PASS1 108/1000] n_scheda=41293
# [PASS1 109/1000] n_scheda=41294
# [PASS1 110/1000] n_scheda=41295
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=105 not_found=5 | SBN=93 OL=12 LoC=0 IA=0
# [PASS1 111/1000] n_scheda=41296
# [PASS1 112/1000] n_scheda=41297
# [PASS1 113/1000] n_scheda=41298
# [PASS1 114/1000] n_scheda=41299
# [PASS1 115/1000] n_scheda=41300
# [PASS1 116/1000] n_scheda=41301
# [PASS1 117/1000] n_scheda=41302
# [PASS1 118/1000] n_scheda=41303
# [PASS1 119/1000] n_scheda=41304
# [PASS1 120/1000] n_scheda=41305
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=114 not_found=6 | SBN=102 OL=12 LoC=0 IA=0
# [PASS1 121/1000] n_scheda=41306
# [PASS1 122/1000] n_scheda=41307
# [PASS1 123/1000] n_scheda=41308
# [PASS1 124/1000] n_scheda=41309
# [PASS1 125/1000] n_scheda=41310
# [PASS1 126/1000] n_scheda=41311
# [PASS1 127/1000] n_scheda=41312
# [PASS1 128/1000] n_scheda=41313
# [PASS1 129/1000] n_scheda=41314
# [PASS1 130/1000] n_scheda=41315
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=124 not_found=6 | SBN=112 OL=12 LoC=0 IA=0
# [PASS1 131/1000] n_scheda=41316
# [PASS1 132/1000] n_scheda=41317
# [PASS1 133/1000] n_scheda=41318
# [PASS1 134/1000] n_scheda=41319
# [PASS1 135/1000] n_scheda=41320
# [PASS1 136/1000] n_scheda=41321
# [PASS1 137/1000] n_scheda=41322
# [PASS1 138/1000] n_scheda=41323
# [PASS1 139/1000] n_scheda=41324
# [PASS1 140/1000] n_scheda=41325
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=131 not_found=9 | SBN=118 OL=13 LoC=0 IA=0
# [PASS1 141/1000] n_scheda=41326
# [PASS1 142/1000] n_scheda=41327
# [PASS1 143/1000] n_scheda=41328
# [PASS1 144/1000] n_scheda=41329
# [PASS1 145/1000] n_scheda=41330
# [PASS1 146/1000] n_scheda=41331
# [PASS1 147/1000] n_scheda=41332
# [PASS1 148/1000] n_scheda=41333
# [PASS1 149/1000] n_scheda=41334
# [PASS1 150/1000] n_scheda=41335
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=140 not_found=10 | SBN=126 OL=14 LoC=0 IA=0
# [PASS1 151/1000] n_scheda=41336
# [PASS1 152/1000] n_scheda=41337
# [PASS1 153/1000] n_scheda=41338
# [PASS1 154/1000] n_scheda=41339
# [PASS1 155/1000] n_scheda=41340
# [PASS1 156/1000] n_scheda=41341
# [PASS1 157/1000] n_scheda=41342
# [PASS1 158/1000] n_scheda=41343
# [PASS1 159/1000] n_scheda=41344
# [PASS1 160/1000] n_scheda=41345
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=150 not_found=10 | SBN=136 OL=14 LoC=0 IA=0
# [PASS1 161/1000] n_scheda=41346
# [PASS1 162/1000] n_scheda=41347
# [PASS1 163/1000] n_scheda=41348
# [PASS1 164/1000] n_scheda=41349
# [PASS1 165/1000] n_scheda=41350
# [PASS1 166/1000] n_scheda=41351
# [PASS1 167/1000] n_scheda=41352
# [PASS1 168/1000] n_scheda=41353
# [PASS1 169/1000] n_scheda=41354
# [PASS1 170/1000] n_scheda=41355
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=160 not_found=10 | SBN=146 OL=14 LoC=0 IA=0
# [PASS1 171/1000] n_scheda=41356
# [PASS1 172/1000] n_scheda=41357
# [PASS1 173/1000] n_scheda=41358
# [PASS1 174/1000] n_scheda=41359
# [PASS1 175/1000] n_scheda=41360
# [PASS1 176/1000] n_scheda=41361
# [PASS1 177/1000] n_scheda=41362
# [PASS1 178/1000] n_scheda=41363
# [PASS1 179/1000] n_scheda=41364
# [PASS1 180/1000] n_scheda=41365
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=169 not_found=11 | SBN=155 OL=14 LoC=0 IA=0
# [PASS1 181/1000] n_scheda=41366
# [PASS1 182/1000] n_scheda=41367
# [PASS1 183/1000] n_scheda=41368
# [PASS1 184/1000] n_scheda=41369
# [PASS1 185/1000] n_scheda=41370
# [PASS1 186/1000] n_scheda=41371
# [PASS1 187/1000] n_scheda=41372
# [PASS1 188/1000] n_scheda=41373
# [PASS1 189/1000] n_scheda=41374
# [PASS1 190/1000] n_scheda=41375
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=175 not_found=15 | SBN=160 OL=15 LoC=0 IA=0
# [PASS1 191/1000] n_scheda=41376
# [PASS1 192/1000] n_scheda=41377
# [PASS1 193/1000] n_scheda=41378
# [PASS1 194/1000] n_scheda=41379
# [PASS1 195/1000] n_scheda=41380
# [PASS1 196/1000] n_scheda=41381
# [PASS1 197/1000] n_scheda=41382
# [PASS1 198/1000] n_scheda=41383
# [PASS1 199/1000] n_scheda=41384
# [PASS1 200/1000] n_scheda=41385
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=185 not_found=15 | SBN=170 OL=15 LoC=0 IA=0
# [PASS1 201/1000] n_scheda=41386
# [PASS1 202/1000] n_scheda=41387
# [PASS1 203/1000] n_scheda=41388
# [PASS1 204/1000] n_scheda=41389
# [PASS1 205/1000] n_scheda=41390
# [PASS1 206/1000] n_scheda=41391
# [PASS1 207/1000] n_scheda=41392
# [PASS1 208/1000] n_scheda=41393
# [PASS1 209/1000] n_scheda=41394
# [PASS1 210/1000] n_scheda=41395
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=194 not_found=16 | SBN=179 OL=15 LoC=0 IA=0
# [PASS1 211/1000] n_scheda=41396
# [PASS1 212/1000] n_scheda=41397
# [PASS1 213/1000] n_scheda=41398
# [PASS1 214/1000] n_scheda=41399
# [PASS1 215/1000] n_scheda=41400
# [PASS1 216/1000] n_scheda=41401
# [PASS1 217/1000] n_scheda=41402
# [PASS1 218/1000] n_scheda=41403
# [PASS1 219/1000] n_scheda=41404
# [PASS1 220/1000] n_scheda=41405
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=203 not_found=17 | SBN=182 OL=20 LoC=0 IA=1
# [PASS1 221/1000] n_scheda=41406
# [PASS1 222/1000] n_scheda=41407
# [PASS1 223/1000] n_scheda=41408
# [PASS1 224/1000] n_scheda=41409
# [PASS1 225/1000] n_scheda=41410
# [PASS1 226/1000] n_scheda=41411
# [PASS1 227/1000] n_scheda=41412
# [PASS1 228/1000] n_scheda=41413
# [PASS1 229/1000] n_scheda=41414
# [PASS1 230/1000] n_scheda=41415
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=212 not_found=18 | SBN=191 OL=20 LoC=0 IA=1
# [PASS1 231/1000] n_scheda=41416
# [PASS1 232/1000] n_scheda=41417
# [PASS1 233/1000] n_scheda=41418
# [PASS1 234/1000] n_scheda=41419
# [PASS1 235/1000] n_scheda=41420
# [PASS1 236/1000] n_scheda=41421
# [PASS1 237/1000] n_scheda=41422
# [PASS1 238/1000] n_scheda=41423
# [PASS1 239/1000] n_scheda=41424
# [PASS1 240/1000] n_scheda=41425
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=221 not_found=19 | SBN=198 OL=22 LoC=0 IA=1
# [PASS1 241/1000] n_scheda=41426
# [PASS1 242/1000] n_scheda=41427
# [PASS1 243/1000] n_scheda=41428
# [PASS1 244/1000] n_scheda=41429
# [PASS1 245/1000] n_scheda=41430
# [PASS1 246/1000] n_scheda=41431
# [PASS1 247/1000] n_scheda=41432
# [PASS1 248/1000] n_scheda=41433
# [PASS1 249/1000] n_scheda=41434
# [PASS1 250/1000] n_scheda=41435
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=229 not_found=21 | SBN=206 OL=22 LoC=0 IA=1
# [PASS1 251/1000] n_scheda=41436
# [PASS1 252/1000] n_scheda=41437
# [PASS1 253/1000] n_scheda=41438
# [PASS1 254/1000] n_scheda=41439
# [PASS1 255/1000] n_scheda=41440
# [PASS1 256/1000] n_scheda=41441
# [PASS1 257/1000] n_scheda=41442
# [PASS1 258/1000] n_scheda=41443
# [PASS1 259/1000] n_scheda=41444
# [PASS1 260/1000] n_scheda=41445
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=237 not_found=23 | SBN=209 OL=25 LoC=2 IA=1
# [PASS1 261/1000] n_scheda=41446
# [PASS1 262/1000] n_scheda=41447
# [PASS1 263/1000] n_scheda=41448
# [PASS1 264/1000] n_scheda=41449
# [PASS1 265/1000] n_scheda=41450
# [PASS1 266/1000] n_scheda=41451
# [PASS1 267/1000] n_scheda=41452
# [PASS1 268/1000] n_scheda=41453
# [PASS1 269/1000] n_scheda=41454
# [PASS1 270/1000] n_scheda=41455
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=245 not_found=25 | SBN=213 OL=29 LoC=2 IA=1
# [PASS1 271/1000] n_scheda=41456
# [PASS1 272/1000] n_scheda=41457
# [PASS1 273/1000] n_scheda=41458
# [PASS1 274/1000] n_scheda=41459
# [PASS1 275/1000] n_scheda=41460
# [PASS1 276/1000] n_scheda=41461
# [PASS1 277/1000] n_scheda=41462
# [PASS1 278/1000] n_scheda=41463
# [PASS1 279/1000] n_scheda=41464
# [PASS1 280/1000] n_scheda=41465
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=254 not_found=26 | SBN=221 OL=30 LoC=2 IA=1
# [PASS1 281/1000] n_scheda=41466
# [PASS1 282/1000] n_scheda=41467
# [PASS1 283/1000] n_scheda=41468
# [PASS1 284/1000] n_scheda=41469
# [PASS1 285/1000] n_scheda=41470
# [PASS1 286/1000] n_scheda=41471
# [PASS1 287/1000] n_scheda=41472
# [PASS1 288/1000] n_scheda=41473
# [PASS1 289/1000] n_scheda=41474
# [PASS1 290/1000] n_scheda=41475
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=264 not_found=26 | SBN=231 OL=30 LoC=2 IA=1
# [PASS1 291/1000] n_scheda=41476
# [PASS1 292/1000] n_scheda=41477
# [PASS1 293/1000] n_scheda=41478
# [PASS1 294/1000] n_scheda=41479
# [PASS1 295/1000] n_scheda=41480
# [PASS1 296/1000] n_scheda=41481
# [PASS1 297/1000] n_scheda=41482
# [PASS1 298/1000] n_scheda=41483
# [PASS1 299/1000] n_scheda=41484
# [PASS1 300/1000] n_scheda=41485
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=272 not_found=28 | SBN=239 OL=30 LoC=2 IA=1
# [PASS1 301/1000] n_scheda=41486
# [PASS1 302/1000] n_scheda=41487
# [PASS1 303/1000] n_scheda=41488
# [PASS1 304/1000] n_scheda=41489
# [PASS1 305/1000] n_scheda=41490
# [PASS1 306/1000] n_scheda=41491
# [PASS1 307/1000] n_scheda=41492
# [PASS1 308/1000] n_scheda=41493
# [PASS1 309/1000] n_scheda=41494
# [PASS1 310/1000] n_scheda=41495
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=279 not_found=31 | SBN=246 OL=30 LoC=2 IA=1
# [PASS1 311/1000] n_scheda=41496
# [PASS1 312/1000] n_scheda=41497
# [PASS1 313/1000] n_scheda=41498
# [PASS1 314/1000] n_scheda=41499
# [PASS1 315/1000] n_scheda=41500
# [PASS1 316/1000] n_scheda=41501
# [PASS1 317/1000] n_scheda=41502
# [PASS1 318/1000] n_scheda=41503
# [PASS1 319/1000] n_scheda=41504
# [PASS1 320/1000] n_scheda=41505
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=289 not_found=31 | SBN=256 OL=30 LoC=2 IA=1
# [PASS1 321/1000] n_scheda=41506
# [PASS1 322/1000] n_scheda=41507
# [PASS1 323/1000] n_scheda=41508
# [PASS1 324/1000] n_scheda=41509
# [PASS1 325/1000] n_scheda=41510
# [PASS1 326/1000] n_scheda=41511
# [PASS1 327/1000] n_scheda=41512
# [PASS1 328/1000] n_scheda=41513
# [PASS1 329/1000] n_scheda=41514
# [PASS1 330/1000] n_scheda=41515
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=291 not_found=39 | SBN=256 OL=32 LoC=2 IA=1
# [PASS1 331/1000] n_scheda=41516
# [PASS1 332/1000] n_scheda=41517
# [PASS1 333/1000] n_scheda=41518
# [PASS1 334/1000] n_scheda=41519
# [PASS1 335/1000] n_scheda=41520
# [PASS1 336/1000] n_scheda=41521
# [PASS1 337/1000] n_scheda=41522
# [PASS1 338/1000] n_scheda=41523
# [PASS1 339/1000] n_scheda=41524
# [PASS1 340/1000] n_scheda=41525
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=298 not_found=42 | SBN=263 OL=32 LoC=2 IA=1
# [PASS1 341/1000] n_scheda=41526
# [PASS1 342/1000] n_scheda=41527
# [PASS1 343/1000] n_scheda=41528
# [PASS1 344/1000] n_scheda=41529
# [PASS1 345/1000] n_scheda=41530
# [PASS1 346/1000] n_scheda=41531
# [PASS1 347/1000] n_scheda=41532
# [PASS1 348/1000] n_scheda=41533
# [PASS1 349/1000] n_scheda=41534
# [PASS1 350/1000] n_scheda=41535
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=306 not_found=44 | SBN=270 OL=33 LoC=2 IA=1
# [PASS1 351/1000] n_scheda=41536
# [PASS1 352/1000] n_scheda=41537
# [PASS1 353/1000] n_scheda=41538
# [PASS1 354/1000] n_scheda=41539
# [PASS1 355/1000] n_scheda=41540
# [PASS1 356/1000] n_scheda=41541
# [PASS1 357/1000] n_scheda=41542
# [PASS1 358/1000] n_scheda=41543
# [PASS1 359/1000] n_scheda=41544
# [PASS1 360/1000] n_scheda=41545
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=312 not_found=48 | SBN=276 OL=33 LoC=2 IA=1
# [PASS1 361/1000] n_scheda=41546
# [PASS1 362/1000] n_scheda=41547
# [PASS1 363/1000] n_scheda=41548
# [PASS1 364/1000] n_scheda=41549
# [PASS1 365/1000] n_scheda=41550
# [PASS1 366/1000] n_scheda=41551
# [PASS1 367/1000] n_scheda=41552
# [PASS1 368/1000] n_scheda=41553
# [PASS1 369/1000] n_scheda=41554
# [PASS1 370/1000] n_scheda=41555
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=318 not_found=52 | SBN=282 OL=33 LoC=2 IA=1
# [PASS1 371/1000] n_scheda=41556
# [PASS1 372/1000] n_scheda=41557
# [PASS1 373/1000] n_scheda=41558
# [PASS1 374/1000] n_scheda=41559
# [PASS1 375/1000] n_scheda=41560
# [PASS1 376/1000] n_scheda=41561
# [PASS1 377/1000] n_scheda=41562
# [PASS1 378/1000] n_scheda=41563
# [PASS1 379/1000] n_scheda=41564
# [PASS1 380/1000] n_scheda=41565
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=326 not_found=54 | SBN=289 OL=34 LoC=2 IA=1
# [PASS1 381/1000] n_scheda=41566
# [PASS1 382/1000] n_scheda=41567
# [PASS1 383/1000] n_scheda=41568
# [PASS1 384/1000] n_scheda=41569
# [PASS1 385/1000] n_scheda=41570
# [PASS1 386/1000] n_scheda=41571
# [PASS1 387/1000] n_scheda=41572
# [PASS1 388/1000] n_scheda=41573
# [PASS1 389/1000] n_scheda=41574
# [PASS1 390/1000] n_scheda=41575
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=335 not_found=55 | SBN=298 OL=34 LoC=2 IA=1
# [PASS1 391/1000] n_scheda=41576
# [PASS1 392/1000] n_scheda=41577
# [PASS1 393/1000] n_scheda=41578
# [PASS1 394/1000] n_scheda=41579
# [PASS1 395/1000] n_scheda=41580
# [PASS1 396/1000] n_scheda=41581
# [PASS1 397/1000] n_scheda=41582
# [PASS1 398/1000] n_scheda=41583
# [PASS1 399/1000] n_scheda=41584
# [PASS1 400/1000] n_scheda=41585
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=344 not_found=56 | SBN=307 OL=34 LoC=2 IA=1
# [PASS1 401/1000] n_scheda=41586
# [PASS1 402/1000] n_scheda=41587
# [PASS1 403/1000] n_scheda=41588
# [PASS1 404/1000] n_scheda=41589
# [PASS1 405/1000] n_scheda=41590
# [PASS1 406/1000] n_scheda=41591
# [PASS1 407/1000] n_scheda=41592
# [PASS1 408/1000] n_scheda=41593
# [PASS1 409/1000] n_scheda=41594
# [PASS1 410/1000] n_scheda=41595
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=352 not_found=58 | SBN=315 OL=34 LoC=2 IA=1
# [PASS1 411/1000] n_scheda=41596
# [PASS1 412/1000] n_scheda=41597
# [PASS1 413/1000] n_scheda=41598
# [PASS1 414/1000] n_scheda=41599
# [PASS1 415/1000] n_scheda=41600
# [PASS1 416/1000] n_scheda=41601
# [PASS1 417/1000] n_scheda=41602
# [PASS1 418/1000] n_scheda=41603
# [PASS1 419/1000] n_scheda=41604
# [PASS1 420/1000] n_scheda=41605
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=359 not_found=61 | SBN=322 OL=34 LoC=2 IA=1
# [PASS1 421/1000] n_scheda=41606
# [PASS1 422/1000] n_scheda=41607
# [PASS1 423/1000] n_scheda=41608
# [PASS1 424/1000] n_scheda=41609
# [PASS1 425/1000] n_scheda=41610
# [PASS1 426/1000] n_scheda=41611
# [PASS1 427/1000] n_scheda=41612
# [PASS1 428/1000] n_scheda=41613
# [PASS1 429/1000] n_scheda=41614
# [PASS1 430/1000] n_scheda=41615
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=367 not_found=63 | SBN=329 OL=35 LoC=2 IA=1
# [PASS1 431/1000] n_scheda=41616
# [PASS1 432/1000] n_scheda=41617
# [PASS1 433/1000] n_scheda=41618
# [PASS1 434/1000] n_scheda=41619
# [PASS1 435/1000] n_scheda=41620
# [PASS1 436/1000] n_scheda=41621
# [PASS1 437/1000] n_scheda=41622
# [PASS1 438/1000] n_scheda=41623
# [PASS1 439/1000] n_scheda=41624
# [PASS1 440/1000] n_scheda=41625
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=373 not_found=67 | SBN=335 OL=35 LoC=2 IA=1
# [PASS1 441/1000] n_scheda=41626
# [PASS1 442/1000] n_scheda=41627
# [PASS1 443/1000] n_scheda=41628
# [PASS1 444/1000] n_scheda=41629
# [PASS1 445/1000] n_scheda=41630
# [PASS1 446/1000] n_scheda=41631
# [PASS1 447/1000] n_scheda=41632
# [PASS1 448/1000] n_scheda=41633
# [PASS1 449/1000] n_scheda=41634
# [PASS1 450/1000] n_scheda=41635
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=382 not_found=68 | SBN=344 OL=35 LoC=2 IA=1
# [PASS1 451/1000] n_scheda=41636
# [PASS1 452/1000] n_scheda=41637
# [PASS1 453/1000] n_scheda=41638
# [PASS1 454/1000] n_scheda=41639
# [PASS1 455/1000] n_scheda=41640
# [PASS1 456/1000] n_scheda=41641
# [PASS1 457/1000] n_scheda=41642
# [PASS1 458/1000] n_scheda=41643
# [PASS1 459/1000] n_scheda=41644
# [PASS1 460/1000] n_scheda=41645
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=386 not_found=74 | SBN=348 OL=35 LoC=2 IA=1
# [PASS1 461/1000] n_scheda=41646
# [PASS1 462/1000] n_scheda=41647
# [PASS1 463/1000] n_scheda=41648
# [PASS1 464/1000] n_scheda=41649
# [PASS1 465/1000] n_scheda=41650
# [PASS1 466/1000] n_scheda=41651
# [PASS1 467/1000] n_scheda=41652
# [PASS1 468/1000] n_scheda=41653
# [PASS1 469/1000] n_scheda=41654
# [PASS1 470/1000] n_scheda=41655
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=391 not_found=79 | SBN=353 OL=35 LoC=2 IA=1
# [PASS1 471/1000] n_scheda=41656
# [PASS1 472/1000] n_scheda=41657
# [PASS1 473/1000] n_scheda=41658
# [PASS1 474/1000] n_scheda=41659
# [PASS1 475/1000] n_scheda=41660
# [PASS1 476/1000] n_scheda=41661
# [PASS1 477/1000] n_scheda=41662
# [PASS1 478/1000] n_scheda=41663
# [PASS1 479/1000] n_scheda=41664
# [PASS1 480/1000] n_scheda=41665
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=396 not_found=84 | SBN=358 OL=35 LoC=2 IA=1
# [PASS1 481/1000] n_scheda=41666
# [PASS1 482/1000] n_scheda=41667
# [PASS1 483/1000] n_scheda=41668
# [PASS1 484/1000] n_scheda=41669
# [PASS1 485/1000] n_scheda=41670
# [PASS1 486/1000] n_scheda=41671
# [PASS1 487/1000] n_scheda=41672
# [PASS1 488/1000] n_scheda=41673
# [PASS1 489/1000] n_scheda=41674
# [PASS1 490/1000] n_scheda=41675
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=400 not_found=90 | SBN=362 OL=35 LoC=2 IA=1
# [PASS1 491/1000] n_scheda=41676
# [PASS1 492/1000] n_scheda=41677
# [PASS1 493/1000] n_scheda=41678
# [PASS1 494/1000] n_scheda=41679
# [PASS1 495/1000] n_scheda=41680
# [PASS1 496/1000] n_scheda=41681
# [PASS1 497/1000] n_scheda=41682
# [PASS1 498/1000] n_scheda=41683
# [PASS1 499/1000] n_scheda=41684
# [PASS1 500/1000] n_scheda=41685
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=404 not_found=96 | SBN=366 OL=35 LoC=2 IA=1
# [PASS1 501/1000] n_scheda=41686
# [PASS1 502/1000] n_scheda=41687
# [PASS1 503/1000] n_scheda=41688
# [PASS1 504/1000] n_scheda=41689
# [PASS1 505/1000] n_scheda=41690
# [PASS1 506/1000] n_scheda=41691
# [PASS1 507/1000] n_scheda=41692
# [PASS1 508/1000] n_scheda=41693
# [PASS1 509/1000] n_scheda=41694
# [PASS1 510/1000] n_scheda=41695
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=409 not_found=101 | SBN=371 OL=35 LoC=2 IA=1
# [PASS1 511/1000] n_scheda=41696
# [PASS1 512/1000] n_scheda=41697
# [PASS1 513/1000] n_scheda=41698
# [PASS1 514/1000] n_scheda=41699
# [PASS1 515/1000] n_scheda=41700
# [PASS1 516/1000] n_scheda=41701
# [PASS1 517/1000] n_scheda=41702
# [PASS1 518/1000] n_scheda=41703
# [PASS1 519/1000] n_scheda=41704
# [PASS1 520/1000] n_scheda=41705
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=415 not_found=105 | SBN=377 OL=35 LoC=2 IA=1
# [PASS1 521/1000] n_scheda=41706
# [PASS1 522/1000] n_scheda=41707
# [PASS1 523/1000] n_scheda=41708
# [PASS1 524/1000] n_scheda=41709
# [PASS1 525/1000] n_scheda=41710
# [PASS1 526/1000] n_scheda=41711
# [PASS1 527/1000] n_scheda=41712
# [PASS1 528/1000] n_scheda=41713
# [PASS1 529/1000] n_scheda=41714
# [PASS1 530/1000] n_scheda=41715
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=417 not_found=113 | SBN=379 OL=35 LoC=2 IA=1
# [PASS1 531/1000] n_scheda=41716
# [PASS1 532/1000] n_scheda=41717
# [PASS1 533/1000] n_scheda=41718
# [PASS1 534/1000] n_scheda=41719
# [PASS1 535/1000] n_scheda=41720
# [PASS1 536/1000] n_scheda=41721
# [PASS1 537/1000] n_scheda=41722
# [PASS1 538/1000] n_scheda=41723
# [PASS1 539/1000] n_scheda=41724
# [PASS1 540/1000] n_scheda=41725
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=421 not_found=119 | SBN=382 OL=36 LoC=2 IA=1
# [PASS1 541/1000] n_scheda=41726
# [PASS1 542/1000] n_scheda=41727
# [PASS1 543/1000] n_scheda=41728
# [PASS1 544/1000] n_scheda=41729
# [PASS1 545/1000] n_scheda=41730
# [PASS1 546/1000] n_scheda=41731
# [PASS1 547/1000] n_scheda=41732
# [PASS1 548/1000] n_scheda=41733
# [PASS1 549/1000] n_scheda=41734
# [PASS1 550/1000] n_scheda=41735
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=426 not_found=124 | SBN=384 OL=36 LoC=5 IA=1
# [PASS1 551/1000] n_scheda=41736
# [PASS1 552/1000] n_scheda=41737
# [PASS1 553/1000] n_scheda=41738
# [PASS1 554/1000] n_scheda=41739
# [PASS1 555/1000] n_scheda=41740
# [PASS1 556/1000] n_scheda=41741
# [PASS1 557/1000] n_scheda=41742
# [PASS1 558/1000] n_scheda=41743
# [PASS1 559/1000] n_scheda=41744
# [PASS1 560/1000] n_scheda=41745
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=432 not_found=128 | SBN=390 OL=36 LoC=5 IA=1
# [PASS1 561/1000] n_scheda=41746
# [PASS1 562/1000] n_scheda=41747
# [PASS1 563/1000] n_scheda=41748
# [PASS1 564/1000] n_scheda=41749
# [PASS1 565/1000] n_scheda=41750
# [PASS1 566/1000] n_scheda=41751
# [PASS1 567/1000] n_scheda=41752
# [PASS1 568/1000] n_scheda=41753
# [PASS1 569/1000] n_scheda=41754
# [PASS1 570/1000] n_scheda=41755
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=438 not_found=132 | SBN=394 OL=38 LoC=5 IA=1
# [PASS1 571/1000] n_scheda=41756
# [PASS1 572/1000] n_scheda=41757
# [PASS1 573/1000] n_scheda=41758
# [PASS1 574/1000] n_scheda=41759
# [PASS1 575/1000] n_scheda=41760
# [PASS1 576/1000] n_scheda=41761
# [PASS1 577/1000] n_scheda=41762
# [PASS1 578/1000] n_scheda=41763
# [PASS1 579/1000] n_scheda=41764
# [PASS1 580/1000] n_scheda=41765
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=441 not_found=139 | SBN=396 OL=38 LoC=6 IA=1
# [PASS1 581/1000] n_scheda=41766
# [PASS1 582/1000] n_scheda=41767
# [PASS1 583/1000] n_scheda=41768
# [PASS1 584/1000] n_scheda=41769
# [PASS1 585/1000] n_scheda=41770
# [PASS1 586/1000] n_scheda=41771
# [PASS1 587/1000] n_scheda=41772
# [PASS1 588/1000] n_scheda=41773
# [PASS1 589/1000] n_scheda=41774
# [PASS1 590/1000] n_scheda=41775
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=448 not_found=142 | SBN=402 OL=38 LoC=7 IA=1
# [PASS1 591/1000] n_scheda=41776
# [PASS1 592/1000] n_scheda=41777
# [PASS1 593/1000] n_scheda=41778
# [PASS1 594/1000] n_scheda=41779
# [PASS1 595/1000] n_scheda=41780
# [PASS1 596/1000] n_scheda=41781
# [PASS1 597/1000] n_scheda=41782
# [PASS1 598/1000] n_scheda=41783
# [PASS1 599/1000] n_scheda=41784
# [PASS1 600/1000] n_scheda=41785
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=450 not_found=150 | SBN=404 OL=38 LoC=7 IA=1
# [PASS1 601/1000] n_scheda=41786
# [PASS1 602/1000] n_scheda=41787
# [PASS1 603/1000] n_scheda=41788
# [PASS1 604/1000] n_scheda=41789
# [PASS1 605/1000] n_scheda=41790
# [PASS1 606/1000] n_scheda=41791
# [PASS1 607/1000] n_scheda=41792
# [PASS1 608/1000] n_scheda=41793
# [PASS1 609/1000] n_scheda=41794
# [PASS1 610/1000] n_scheda=41795
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=459 not_found=151 | SBN=413 OL=38 LoC=7 IA=1
# [PASS1 611/1000] n_scheda=41796
# [PASS1 612/1000] n_scheda=41797
# [PASS1 613/1000] n_scheda=41798
# [PASS1 614/1000] n_scheda=41799
# [PASS1 615/1000] n_scheda=41800
# [PASS1 616/1000] n_scheda=41801
# [PASS1 617/1000] n_scheda=41802
# [PASS1 618/1000] n_scheda=41803
# [PASS1 619/1000] n_scheda=41804
# [PASS1 620/1000] n_scheda=41805
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=466 not_found=154 | SBN=420 OL=38 LoC=7 IA=1
# [PASS1 621/1000] n_scheda=41806
# [PASS1 622/1000] n_scheda=41807
# [PASS1 623/1000] n_scheda=41808
# [PASS1 624/1000] n_scheda=41809
# [PASS1 625/1000] n_scheda=41810
# [PASS1 626/1000] n_scheda=41811
# [PASS1 627/1000] n_scheda=41812
# [PASS1 628/1000] n_scheda=41813
# [PASS1 629/1000] n_scheda=41814
# [PASS1 630/1000] n_scheda=41815
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=474 not_found=156 | SBN=428 OL=38 LoC=7 IA=1
# [PASS1 631/1000] n_scheda=41816
# [PASS1 632/1000] n_scheda=41817
# [PASS1 633/1000] n_scheda=41818
# [PASS1 634/1000] n_scheda=41819
# [PASS1 635/1000] n_scheda=41820
# [PASS1 636/1000] n_scheda=41821
# [PASS1 637/1000] n_scheda=41822
# [PASS1 638/1000] n_scheda=41823
# [PASS1 639/1000] n_scheda=41824
# [PASS1 640/1000] n_scheda=41825
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=480 not_found=160 | SBN=434 OL=38 LoC=7 IA=1
# [PASS1 641/1000] n_scheda=41826
# [PASS1 642/1000] n_scheda=41827
# [PASS1 643/1000] n_scheda=41828
# [PASS1 644/1000] n_scheda=41829
# [PASS1 645/1000] n_scheda=41830
# [PASS1 646/1000] n_scheda=41831
# [PASS1 647/1000] n_scheda=41832
# [PASS1 648/1000] n_scheda=41833
# [PASS1 649/1000] n_scheda=41834
# [PASS1 650/1000] n_scheda=41835
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=488 not_found=162 | SBN=442 OL=38 LoC=7 IA=1
# [PASS1 651/1000] n_scheda=41836
# [PASS1 652/1000] n_scheda=41837
# [PASS1 653/1000] n_scheda=41838
# [PASS1 654/1000] n_scheda=41839
# [PASS1 655/1000] n_scheda=41840
# [PASS1 656/1000] n_scheda=41841
# [PASS1 657/1000] n_scheda=41842
# [PASS1 658/1000] n_scheda=41843
# [PASS1 659/1000] n_scheda=41844
# [PASS1 660/1000] n_scheda=41845
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=495 not_found=165 | SBN=448 OL=39 LoC=7 IA=1
# [PASS1 661/1000] n_scheda=41846
# [PASS1 662/1000] n_scheda=41847
# [PASS1 663/1000] n_scheda=41848
# [PASS1 664/1000] n_scheda=41849
# [PASS1 665/1000] n_scheda=41850
# [PASS1 666/1000] n_scheda=41851
# [PASS1 667/1000] n_scheda=41852
# [PASS1 668/1000] n_scheda=41853
# [PASS1 669/1000] n_scheda=41854
# [PASS1 670/1000] n_scheda=41855
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=502 not_found=168 | SBN=455 OL=39 LoC=7 IA=1
# [PASS1 671/1000] n_scheda=41856
# [PASS1 672/1000] n_scheda=41857
# [PASS1 673/1000] n_scheda=41858
# [PASS1 674/1000] n_scheda=41859
# [PASS1 675/1000] n_scheda=41860
# [PASS1 676/1000] n_scheda=41861
# [PASS1 677/1000] n_scheda=41862
# [PASS1 678/1000] n_scheda=41863
# [PASS1 679/1000] n_scheda=41864
# [PASS1 680/1000] n_scheda=41865
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=507 not_found=173 | SBN=460 OL=39 LoC=7 IA=1
# [PASS1 681/1000] n_scheda=41866
# [PASS1 682/1000] n_scheda=41867
# [PASS1 683/1000] n_scheda=41868
# [PASS1 684/1000] n_scheda=41869
# [PASS1 685/1000] n_scheda=41870
# [PASS1 686/1000] n_scheda=41871
# [PASS1 687/1000] n_scheda=41872
# [PASS1 688/1000] n_scheda=41873
# [PASS1 689/1000] n_scheda=41874
# [PASS1 690/1000] n_scheda=41875
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=514 not_found=176 | SBN=467 OL=39 LoC=7 IA=1
# [PASS1 691/1000] n_scheda=41876
# [PASS1 692/1000] n_scheda=41877
# [PASS1 693/1000] n_scheda=41878
# [PASS1 694/1000] n_scheda=41879
# [PASS1 695/1000] n_scheda=41880
# [PASS1 696/1000] n_scheda=41881
# [PASS1 697/1000] n_scheda=41882
# [PASS1 698/1000] n_scheda=41883
# [PASS1 699/1000] n_scheda=41884
# [PASS1 700/1000] n_scheda=41885
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=524 not_found=176 | SBN=477 OL=39 LoC=7 IA=1
# [PASS1 701/1000] n_scheda=41886
# [PASS1 702/1000] n_scheda=41887
# [PASS1 703/1000] n_scheda=41888
# [PASS1 704/1000] n_scheda=41889
# [PASS1 705/1000] n_scheda=41890
# [PASS1 706/1000] n_scheda=41891
# [PASS1 707/1000] n_scheda=41892
# [PASS1 708/1000] n_scheda=41893
# [PASS1 709/1000] n_scheda=41894
# [PASS1 710/1000] n_scheda=41895
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=530 not_found=180 | SBN=483 OL=39 LoC=7 IA=1
# [PASS1 711/1000] n_scheda=41896
# [PASS1 712/1000] n_scheda=41897
# [PASS1 713/1000] n_scheda=41898
# [PASS1 714/1000] n_scheda=41899
# [PASS1 715/1000] n_scheda=41900
# [PASS1 716/1000] n_scheda=41901
# [PASS1 717/1000] n_scheda=41902
# [PASS1 718/1000] n_scheda=41903
# [PASS1 719/1000] n_scheda=41904
# [PASS1 720/1000] n_scheda=41905
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=536 not_found=184 | SBN=489 OL=39 LoC=7 IA=1
# [PASS1 721/1000] n_scheda=41906
# [PASS1 722/1000] n_scheda=41907
# [PASS1 723/1000] n_scheda=41908
# [PASS1 724/1000] n_scheda=41909
# [PASS1 725/1000] n_scheda=41910
# [PASS1 726/1000] n_scheda=41911
# [PASS1 727/1000] n_scheda=41912
# [PASS1 728/1000] n_scheda=41913
# [PASS1 729/1000] n_scheda=41914
# [PASS1 730/1000] n_scheda=41915
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=544 not_found=186 | SBN=497 OL=39 LoC=7 IA=1
# [PASS1 731/1000] n_scheda=41916
# [PASS1 732/1000] n_scheda=41917
# [PASS1 733/1000] n_scheda=41918
# [PASS1 734/1000] n_scheda=41919
# [PASS1 735/1000] n_scheda=41920
# [PASS1 736/1000] n_scheda=41921
# [PASS1 737/1000] n_scheda=41922
# [PASS1 738/1000] n_scheda=41923
# [PASS1 739/1000] n_scheda=41924
# [PASS1 740/1000] n_scheda=41925
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=552 not_found=188 | SBN=505 OL=39 LoC=7 IA=1
# [PASS1 741/1000] n_scheda=41926
# [PASS1 742/1000] n_scheda=41927
# [PASS1 743/1000] n_scheda=41928
# [PASS1 744/1000] n_scheda=41929
# [PASS1 745/1000] n_scheda=41930
# [PASS1 746/1000] n_scheda=41931
# [PASS1 747/1000] n_scheda=41932
# [PASS1 748/1000] n_scheda=41933
# [PASS1 749/1000] n_scheda=41934
# [PASS1 750/1000] n_scheda=41935
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=557 not_found=193 | SBN=510 OL=39 LoC=7 IA=1
# [PASS1 751/1000] n_scheda=41936
# [PASS1 752/1000] n_scheda=41937
# [PASS1 753/1000] n_scheda=41938
# [PASS1 754/1000] n_scheda=41939
# [PASS1 755/1000] n_scheda=41940
# [PASS1 756/1000] n_scheda=41941
# [PASS1 757/1000] n_scheda=41942
# [PASS1 758/1000] n_scheda=41943
# [PASS1 759/1000] n_scheda=41944
# [PASS1 760/1000] n_scheda=41945
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=564 not_found=196 | SBN=517 OL=39 LoC=7 IA=1
# [PASS1 761/1000] n_scheda=41946
# [PASS1 762/1000] n_scheda=41947
# [PASS1 763/1000] n_scheda=41948
# [PASS1 764/1000] n_scheda=41949
# [PASS1 765/1000] n_scheda=41950
# [PASS1 766/1000] n_scheda=41951
# [PASS1 767/1000] n_scheda=41952
# [PASS1 768/1000] n_scheda=41953
# [PASS1 769/1000] n_scheda=41954
# [PASS1 770/1000] n_scheda=41955
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=568 not_found=202 | SBN=521 OL=39 LoC=7 IA=1
# [PASS1 771/1000] n_scheda=41956
# [PASS1 772/1000] n_scheda=41957
# [PASS1 773/1000] n_scheda=41958
# [PASS1 774/1000] n_scheda=41959
# [PASS1 775/1000] n_scheda=41960
# [PASS1 776/1000] n_scheda=41961
# [PASS1 777/1000] n_scheda=41962
# [PASS1 778/1000] n_scheda=41963
# [PASS1 779/1000] n_scheda=41964
# [PASS1 780/1000] n_scheda=41965
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=574 not_found=206 | SBN=527 OL=39 LoC=7 IA=1
# [PASS1 781/1000] n_scheda=41966
# [PASS1 782/1000] n_scheda=41967
# [PASS1 783/1000] n_scheda=41968
# [PASS1 784/1000] n_scheda=41969
# [PASS1 785/1000] n_scheda=41970
# [PASS1 786/1000] n_scheda=41971
# [PASS1 787/1000] n_scheda=41972
# [PASS1 788/1000] n_scheda=41973
# [PASS1 789/1000] n_scheda=41974
# [PASS1 790/1000] n_scheda=41975
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=580 not_found=210 | SBN=533 OL=39 LoC=7 IA=1
# [PASS1 791/1000] n_scheda=41976
# [PASS1 792/1000] n_scheda=41977
# [PASS1 793/1000] n_scheda=41978
# [PASS1 794/1000] n_scheda=41979
# [PASS1 795/1000] n_scheda=41980
# [PASS1 796/1000] n_scheda=41981
# [PASS1 797/1000] n_scheda=41982
# [PASS1 798/1000] n_scheda=41983
# [PASS1 799/1000] n_scheda=41984
# [PASS1 800/1000] n_scheda=41985
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=587 not_found=213 | SBN=540 OL=39 LoC=7 IA=1
# [PASS1 801/1000] n_scheda=41986
# [PASS1 802/1000] n_scheda=41987
# [PASS1 803/1000] n_scheda=41988
# [PASS1 804/1000] n_scheda=41989
# [PASS1 805/1000] n_scheda=41990
# [PASS1 806/1000] n_scheda=41991
# [PASS1 807/1000] n_scheda=41992
# [PASS1 808/1000] n_scheda=41993
# [PASS1 809/1000] n_scheda=41994
# [PASS1 810/1000] n_scheda=41995
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=592 not_found=218 | SBN=545 OL=39 LoC=7 IA=1
# [PASS1 811/1000] n_scheda=41996
# [PASS1 812/1000] n_scheda=41997
# [PASS1 813/1000] n_scheda=41998
# [PASS1 814/1000] n_scheda=41999
# [PASS1 815/1000] n_scheda=42000
# [PASS1 816/1000] n_scheda=42001
# [PASS1 817/1000] n_scheda=42002
# [PASS1 818/1000] n_scheda=42003
# [PASS1 819/1000] n_scheda=42004
# [PASS1 820/1000] n_scheda=42005
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=597 not_found=223 | SBN=550 OL=39 LoC=7 IA=1
# [PASS1 821/1000] n_scheda=42006
# [PASS1 822/1000] n_scheda=42007
# [PASS1 823/1000] n_scheda=42008
# [PASS1 824/1000] n_scheda=42009
# [PASS1 825/1000] n_scheda=42010
# [PASS1 826/1000] n_scheda=42011
# [PASS1 827/1000] n_scheda=42012
# [PASS1 828/1000] n_scheda=42013
# [PASS1 829/1000] n_scheda=42014
# [PASS1 830/1000] n_scheda=42015
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=601 not_found=229 | SBN=554 OL=39 LoC=7 IA=1
# [PASS1 831/1000] n_scheda=42016
# [PASS1 832/1000] n_scheda=42017
# [PASS1 833/1000] n_scheda=42018
# [PASS1 834/1000] n_scheda=42019
# [PASS1 835/1000] n_scheda=42020
# [PASS1 836/1000] n_scheda=42021
# [PASS1 837/1000] n_scheda=42022
# [PASS1 838/1000] n_scheda=42023
# [PASS1 839/1000] n_scheda=42024
# [PASS1 840/1000] n_scheda=42025
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=610 not_found=230 | SBN=562 OL=40 LoC=7 IA=1
# [PASS1 841/1000] n_scheda=42026
# [PASS1 842/1000] n_scheda=42027
# [PASS1 843/1000] n_scheda=42028
# [PASS1 844/1000] n_scheda=42029
# [PASS1 845/1000] n_scheda=42030
# [PASS1 846/1000] n_scheda=42031
# [PASS1 847/1000] n_scheda=42032
# [PASS1 848/1000] n_scheda=42033
# [PASS1 849/1000] n_scheda=42034
# [PASS1 850/1000] n_scheda=42035
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=619 not_found=231 | SBN=571 OL=40 LoC=7 IA=1
# [PASS1 851/1000] n_scheda=42036
# [PASS1 852/1000] n_scheda=42037
# [PASS1 853/1000] n_scheda=42038
# [PASS1 854/1000] n_scheda=42039
# [PASS1 855/1000] n_scheda=42040
# [PASS1 856/1000] n_scheda=42041
# [PASS1 857/1000] n_scheda=42042
# [PASS1 858/1000] n_scheda=42043
# [PASS1 859/1000] n_scheda=42044
# [PASS1 860/1000] n_scheda=42045
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=628 not_found=232 | SBN=580 OL=40 LoC=7 IA=1
# [PASS1 861/1000] n_scheda=42046
# [PASS1 862/1000] n_scheda=42047
# [PASS1 863/1000] n_scheda=42048
# [PASS1 864/1000] n_scheda=42049
# [PASS1 865/1000] n_scheda=42050
# [PASS1 866/1000] n_scheda=42051
# [PASS1 867/1000] n_scheda=42052
# [PASS1 868/1000] n_scheda=42053
# [PASS1 869/1000] n_scheda=42054
# [PASS1 870/1000] n_scheda=42055
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=632 not_found=238 | SBN=584 OL=40 LoC=7 IA=1
# [PASS1 871/1000] n_scheda=42056
# [PASS1 872/1000] n_scheda=42057
# [PASS1 873/1000] n_scheda=42058
# [PASS1 874/1000] n_scheda=42059
# [PASS1 875/1000] n_scheda=42060
# [PASS1 876/1000] n_scheda=42061
# [PASS1 877/1000] n_scheda=42062
# [PASS1 878/1000] n_scheda=42063
# [PASS1 879/1000] n_scheda=42064
# [PASS1 880/1000] n_scheda=42065
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=638 not_found=242 | SBN=590 OL=40 LoC=7 IA=1
# [PASS1 881/1000] n_scheda=42066
# [PASS1 882/1000] n_scheda=42067
# [PASS1 883/1000] n_scheda=42068
# [PASS1 884/1000] n_scheda=42069
# [PASS1 885/1000] n_scheda=42070
# [PASS1 886/1000] n_scheda=42071
# [PASS1 887/1000] n_scheda=42072
# [PASS1 888/1000] n_scheda=42073
# [PASS1 889/1000] n_scheda=42074
# [PASS1 890/1000] n_scheda=42075
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=644 not_found=246 | SBN=596 OL=40 LoC=7 IA=1
# [PASS1 891/1000] n_scheda=42076
# [PASS1 892/1000] n_scheda=42077
# [PASS1 893/1000] n_scheda=42078
# [PASS1 894/1000] n_scheda=42079
# [PASS1 895/1000] n_scheda=42080
# [PASS1 896/1000] n_scheda=42081
# [PASS1 897/1000] n_scheda=42082
# [PASS1 898/1000] n_scheda=42083
# [PASS1 899/1000] n_scheda=42084
# [PASS1 900/1000] n_scheda=42085
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=652 not_found=248 | SBN=604 OL=40 LoC=7 IA=1
# [PASS1 901/1000] n_scheda=42086
# [PASS1 902/1000] n_scheda=42087
# [PASS1 903/1000] n_scheda=42088
# [PASS1 904/1000] n_scheda=42089
# [PASS1 905/1000] n_scheda=42090
# [PASS1 906/1000] n_scheda=42091
# [PASS1 907/1000] n_scheda=42092
# [PASS1 908/1000] n_scheda=42093
# [PASS1 909/1000] n_scheda=42094
# [PASS1 910/1000] n_scheda=42095
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=660 not_found=250 | SBN=612 OL=40 LoC=7 IA=1
# [PASS1 911/1000] n_scheda=42096
# [PASS1 912/1000] n_scheda=42097
# [PASS1 913/1000] n_scheda=42098
# [PASS1 914/1000] n_scheda=42099
# [PASS1 915/1000] n_scheda=42100
# [PASS1 916/1000] n_scheda=42101
# [PASS1 917/1000] n_scheda=42102
# [PASS1 918/1000] n_scheda=42103
# [PASS1 919/1000] n_scheda=42104
# [PASS1 920/1000] n_scheda=42105
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=662 not_found=258 | SBN=614 OL=40 LoC=7 IA=1
# [PASS1 921/1000] n_scheda=42106
# [PASS1 922/1000] n_scheda=42107
# [PASS1 923/1000] n_scheda=42108
# [PASS1 924/1000] n_scheda=42109
# [PASS1 925/1000] n_scheda=42110
# [PASS1 926/1000] n_scheda=42111
# [PASS1 927/1000] n_scheda=42112
# [PASS1 928/1000] n_scheda=42113
# [PASS1 929/1000] n_scheda=42114
# [PASS1 930/1000] n_scheda=42115
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=665 not_found=265 | SBN=616 OL=41 LoC=7 IA=1
# [PASS1 931/1000] n_scheda=42116
# [PASS1 932/1000] n_scheda=42117
# [PASS1 933/1000] n_scheda=42118
# [PASS1 934/1000] n_scheda=42119
# [PASS1 935/1000] n_scheda=42120
# [PASS1 936/1000] n_scheda=42121
# [PASS1 937/1000] n_scheda=42122
# [PASS1 938/1000] n_scheda=42123
# [PASS1 939/1000] n_scheda=42124
# [PASS1 940/1000] n_scheda=42125
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=669 not_found=271 | SBN=620 OL=41 LoC=7 IA=1
# [PASS1 941/1000] n_scheda=42126
# [PASS1 942/1000] n_scheda=42127
# [PASS1 943/1000] n_scheda=42128
# [PASS1 944/1000] n_scheda=42129
# [PASS1 945/1000] n_scheda=42130
# [PASS1 946/1000] n_scheda=42131
# [PASS1 947/1000] n_scheda=42132
# [PASS1 948/1000] n_scheda=42133
# [PASS1 949/1000] n_scheda=42134
# [PASS1 950/1000] n_scheda=42135
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=671 not_found=279 | SBN=622 OL=41 LoC=7 IA=1
# [PASS1 951/1000] n_scheda=42136
# [PASS1 952/1000] n_scheda=42137
# [PASS1 953/1000] n_scheda=42138
# [PASS1 954/1000] n_scheda=42139
# [PASS1 955/1000] n_scheda=42140
# [PASS1 956/1000] n_scheda=42141
# [PASS1 957/1000] n_scheda=42142
# [PASS1 958/1000] n_scheda=42143
# [PASS1 959/1000] n_scheda=42144
# [PASS1 960/1000] n_scheda=42145
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=678 not_found=282 | SBN=629 OL=41 LoC=7 IA=1
# [PASS1 961/1000] n_scheda=42146
# [PASS1 962/1000] n_scheda=42147
# [PASS1 963/1000] n_scheda=42148
# [PASS1 964/1000] n_scheda=42149
# [PASS1 965/1000] n_scheda=42150
# [PASS1 966/1000] n_scheda=42151
# [PASS1 967/1000] n_scheda=42152
# [PASS1 968/1000] n_scheda=42153
# [PASS1 969/1000] n_scheda=42154
# [PASS1 970/1000] n_scheda=42155
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=686 not_found=284 | SBN=637 OL=41 LoC=7 IA=1
# [PASS1 971/1000] n_scheda=42156
# [PASS1 972/1000] n_scheda=42157
# [PASS1 973/1000] n_scheda=42158
# [PASS1 974/1000] n_scheda=42159
# [PASS1 975/1000] n_scheda=42160
# [PASS1 976/1000] n_scheda=42161
# [PASS1 977/1000] n_scheda=42162
# [PASS1 978/1000] n_scheda=42163
# [PASS1 979/1000] n_scheda=42164
# [PASS1 980/1000] n_scheda=42165
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=690 not_found=290 | SBN=640 OL=42 LoC=7 IA=1
# [PASS1 981/1000] n_scheda=42166
# [PASS1 982/1000] n_scheda=42167
# [PASS1 983/1000] n_scheda=42168
# [PASS1 984/1000] n_scheda=42169
# [PASS1 985/1000] n_scheda=42170
# [PASS1 986/1000] n_scheda=42171
# [PASS1 987/1000] n_scheda=42172
# [PASS1 988/1000] n_scheda=42173
# [PASS1 989/1000] n_scheda=42174
# [PASS1 990/1000] n_scheda=42175
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=693 not_found=297 | SBN=643 OL=42 LoC=7 IA=1
# [PASS1 991/1000] n_scheda=42176
# [PASS1 992/1000] n_scheda=42177
# [PASS1 993/1000] n_scheda=42178
# [PASS1 994/1000] n_scheda=42179
# [PASS1 995/1000] n_scheda=42180
# [PASS1 996/1000] n_scheda=42181
# [PASS1 997/1000] n_scheda=42182
# [PASS1 998/1000] n_scheda=42183
# [PASS1 999/1000] n_scheda=42184
# [PASS1 1000/1000] n_scheda=42185
# Checkpoint PASS1: biblio_longform_all_records_enriched.csv | found=701 not_found=299 | SBN=650 OL=42 LoC=8 IA=1
# PASS1 completed. LONG: biblio_longform_all_records_enriched.csv | found=701 not_found=299 | SBN=650 OL=42 LoC=8 IA=1
# PASS2 starting: NOT_FOUND records = 299
# [PASS2 1/299] n_scheda=41188
# [PASS2 2/299] n_scheda=41189
# [PASS2 3/299] n_scheda=41195
# [PASS2 4/299] n_scheda=41211
# [PASS2 5/299] n_scheda=41251
# [PASS2 6/299] n_scheda=41302
# [PASS2 7/299] n_scheda=41316
# [PASS2 8/299] n_scheda=41317
# [PASS2 9/299] n_scheda=41318
# [PASS2 10/299] n_scheda=41327
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=1 pass2_still_not_found=9 | SBN=0 OL=0 LoC=1 IA=0
# [PASS2 11/299] n_scheda=41365
# [PASS2 12/299] n_scheda=41366
# [PASS2 13/299] n_scheda=41369
# [PASS2 14/299] n_scheda=41374
# [PASS2 15/299] n_scheda=41375
# [PASS2 16/299] n_scheda=41389
# [PASS2 17/299] n_scheda=41403
# [PASS2 18/299] n_scheda=41411
# [PASS2 19/299] n_scheda=41425
# [PASS2 20/299] n_scheda=41429
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=8 pass2_still_not_found=12 | SBN=7 OL=0 LoC=1 IA=0
# [PASS2 21/299] n_scheda=41434
# [PASS2 22/299] n_scheda=41436
# [PASS2 23/299] n_scheda=41438
# [PASS2 24/299] n_scheda=41446
# [PASS2 25/299] n_scheda=41450
# [PASS2 26/299] n_scheda=41465
# [PASS2 27/299] n_scheda=41477
# [PASS2 28/299] n_scheda=41479
# [PASS2 29/299] n_scheda=41486
# [PASS2 30/299] n_scheda=41491
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=15 pass2_still_not_found=15 | SBN=11 OL=3 LoC=1 IA=0
# [PASS2 31/299] n_scheda=41492
# [PASS2 32/299] n_scheda=41506
# [PASS2 33/299] n_scheda=41509
# [PASS2 34/299] n_scheda=41510
# [PASS2 35/299] n_scheda=41511
# [PASS2 36/299] n_scheda=41512
# [PASS2 37/299] n_scheda=41513
# [PASS2 38/299] n_scheda=41514
# [PASS2 39/299] n_scheda=41515
# [PASS2 40/299] n_scheda=41517
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=23 pass2_still_not_found=17 | SBN=15 OL=4 LoC=4 IA=0
# [PASS2 41/299] n_scheda=41518
# [PASS2 42/299] n_scheda=41520
# [PASS2 43/299] n_scheda=41530
# [PASS2 44/299] n_scheda=41533
# [PASS2 45/299] n_scheda=41537
# [PASS2 46/299] n_scheda=41538
# [PASS2 47/299] n_scheda=41540
# [PASS2 48/299] n_scheda=41544
# [PASS2 49/299] n_scheda=41546
# [PASS2 50/299] n_scheda=41547
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=30 pass2_still_not_found=20 | SBN=21 OL=5 LoC=4 IA=0
# [PASS2 51/299] n_scheda=41550
# [PASS2 52/299] n_scheda=41553
# [PASS2 53/299] n_scheda=41563
# [PASS2 54/299] n_scheda=41565
# [PASS2 55/299] n_scheda=41568
# [PASS2 56/299] n_scheda=41585
# [PASS2 57/299] n_scheda=41592
# [PASS2 58/299] n_scheda=41595
# [PASS2 59/299] n_scheda=41596
# [PASS2 60/299] n_scheda=41597
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=34 pass2_still_not_found=26 | SBN=24 OL=6 LoC=4 IA=0
# [PASS2 61/299] n_scheda=41598
# [PASS2 62/299] n_scheda=41607
# [PASS2 63/299] n_scheda=41615
# [PASS2 64/299] n_scheda=41619
# [PASS2 65/299] n_scheda=41621
# [PASS2 66/299] n_scheda=41622
# [PASS2 67/299] n_scheda=41625
# [PASS2 68/299] n_scheda=41633
# [PASS2 69/299] n_scheda=41638
# [PASS2 70/299] n_scheda=41639
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=40 pass2_still_not_found=30 | SBN=27 OL=8 LoC=5 IA=0
# [PASS2 71/299] n_scheda=41642
# [PASS2 72/299] n_scheda=41643
# [PASS2 73/299] n_scheda=41644
# [PASS2 74/299] n_scheda=41645
# [PASS2 75/299] n_scheda=41646
# [PASS2 76/299] n_scheda=41649
# [PASS2 77/299] n_scheda=41650
# [PASS2 78/299] n_scheda=41651
# [PASS2 79/299] n_scheda=41653
# [PASS2 80/299] n_scheda=41656
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=41 pass2_still_not_found=39 | SBN=28 OL=8 LoC=5 IA=0
# [PASS2 81/299] n_scheda=41658
# [PASS2 82/299] n_scheda=41659
# [PASS2 83/299] n_scheda=41660
# [PASS2 84/299] n_scheda=41664
# [PASS2 85/299] n_scheda=41669
# [PASS2 86/299] n_scheda=41670
# [PASS2 87/299] n_scheda=41671
# [PASS2 88/299] n_scheda=41672
# [PASS2 89/299] n_scheda=41673
# [PASS2 90/299] n_scheda=41674
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=47 pass2_still_not_found=43 | SBN=33 OL=9 LoC=5 IA=0
# [PASS2 91/299] n_scheda=41676
# [PASS2 92/299] n_scheda=41679
# [PASS2 93/299] n_scheda=41680
# [PASS2 94/299] n_scheda=41681
# [PASS2 95/299] n_scheda=41683
# [PASS2 96/299] n_scheda=41685
# [PASS2 97/299] n_scheda=41687
# [PASS2 98/299] n_scheda=41691
# [PASS2 99/299] n_scheda=41692
# [PASS2 100/299] n_scheda=41693
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=54 pass2_still_not_found=46 | SBN=40 OL=9 LoC=5 IA=0
# [PASS2 101/299] n_scheda=41694
# [PASS2 102/299] n_scheda=41696
# [PASS2 103/299] n_scheda=41699
# [PASS2 104/299] n_scheda=41703
# [PASS2 105/299] n_scheda=41704
# [PASS2 106/299] n_scheda=41706
# [PASS2 107/299] n_scheda=41707
# [PASS2 108/299] n_scheda=41708
# [PASS2 109/299] n_scheda=41709
# [PASS2 110/299] n_scheda=41710
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=58 pass2_still_not_found=52 | SBN=42 OL=10 LoC=6 IA=0
# [PASS2 111/299] n_scheda=41711
# [PASS2 112/299] n_scheda=41713
# [PASS2 113/299] n_scheda=41715
# [PASS2 114/299] n_scheda=41716
# [PASS2 115/299] n_scheda=41717
# [PASS2 116/299] n_scheda=41719
# [PASS2 117/299] n_scheda=41720
# [PASS2 118/299] n_scheda=41721
# [PASS2 119/299] n_scheda=41723
# [PASS2 120/299] n_scheda=41726
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=67 pass2_still_not_found=53 | SBN=50 OL=10 LoC=7 IA=0
# [PASS2 121/299] n_scheda=41730
# [PASS2 122/299] n_scheda=41733
# [PASS2 123/299] n_scheda=41734
# [PASS2 124/299] n_scheda=41735
# [PASS2 125/299] n_scheda=41736
# [PASS2 126/299] n_scheda=41737
# [PASS2 127/299] n_scheda=41738
# [PASS2 128/299] n_scheda=41739
# [PASS2 129/299] n_scheda=41751
# [PASS2 130/299] n_scheda=41752
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=75 pass2_still_not_found=55 | SBN=57 OL=11 LoC=7 IA=0
# [PASS2 131/299] n_scheda=41753
# [PASS2 132/299] n_scheda=41754
# [PASS2 133/299] n_scheda=41756
# [PASS2 134/299] n_scheda=41757
# [PASS2 135/299] n_scheda=41758
# [PASS2 136/299] n_scheda=41759
# [PASS2 137/299] n_scheda=41760
# [PASS2 138/299] n_scheda=41761
# [PASS2 139/299] n_scheda=41763
# [PASS2 140/299] n_scheda=41766
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=83 pass2_still_not_found=57 | SBN=64 OL=12 LoC=7 IA=0
# [PASS2 141/299] n_scheda=41774
# [PASS2 142/299] n_scheda=41775
# [PASS2 143/299] n_scheda=41776
# [PASS2 144/299] n_scheda=41777
# [PASS2 145/299] n_scheda=41778
# [PASS2 146/299] n_scheda=41780
# [PASS2 147/299] n_scheda=41782
# [PASS2 148/299] n_scheda=41783
# [PASS2 149/299] n_scheda=41784
# [PASS2 150/299] n_scheda=41785
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=85 pass2_still_not_found=65 | SBN=66 OL=12 LoC=7 IA=0
# [PASS2 151/299] n_scheda=41786
# [PASS2 152/299] n_scheda=41801
# [PASS2 153/299] n_scheda=41803
# [PASS2 154/299] n_scheda=41804
# [PASS2 155/299] n_scheda=41807
# [PASS2 156/299] n_scheda=41810
# [PASS2 157/299] n_scheda=41818
# [PASS2 158/299] n_scheda=41820
# [PASS2 159/299] n_scheda=41823
# [PASS2 160/299] n_scheda=41824
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=91 pass2_still_not_found=69 | SBN=71 OL=12 LoC=8 IA=0
# [PASS2 161/299] n_scheda=41828
# [PASS2 162/299] n_scheda=41831
# [PASS2 163/299] n_scheda=41839
# [PASS2 164/299] n_scheda=41840
# [PASS2 165/299] n_scheda=41844
# [PASS2 166/299] n_scheda=41853
# [PASS2 167/299] n_scheda=41854
# [PASS2 168/299] n_scheda=41855
# [PASS2 169/299] n_scheda=41856
# [PASS2 170/299] n_scheda=41857
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=97 pass2_still_not_found=73 | SBN=75 OL=12 LoC=10 IA=0
# [PASS2 171/299] n_scheda=41858
# [PASS2 172/299] n_scheda=41860
# [PASS2 173/299] n_scheda=41865
# [PASS2 174/299] n_scheda=41866
# [PASS2 175/299] n_scheda=41867
# [PASS2 176/299] n_scheda=41872
# [PASS2 177/299] n_scheda=41886
# [PASS2 178/299] n_scheda=41887
# [PASS2 179/299] n_scheda=41889
# [PASS2 180/299] n_scheda=41891
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=98 pass2_still_not_found=82 | SBN=76 OL=12 LoC=10 IA=0
# [PASS2 181/299] n_scheda=41899
# [PASS2 182/299] n_scheda=41902
# [PASS2 183/299] n_scheda=41904
# [PASS2 184/299] n_scheda=41905
# [PASS2 185/299] n_scheda=41907
# [PASS2 186/299] n_scheda=41914
# [PASS2 187/299] n_scheda=41923
# [PASS2 188/299] n_scheda=41924
# [PASS2 189/299] n_scheda=41926
# [PASS2 190/299] n_scheda=41927
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=107 pass2_still_not_found=83 | SBN=85 OL=12 LoC=10 IA=0
# [PASS2 191/299] n_scheda=41928
# [PASS2 192/299] n_scheda=41931
# [PASS2 193/299] n_scheda=41934
# [PASS2 194/299] n_scheda=41938
# [PASS2 195/299] n_scheda=41939
# [PASS2 196/299] n_scheda=41942
# [PASS2 197/299] n_scheda=41946
# [PASS2 198/299] n_scheda=41947
# [PASS2 199/299] n_scheda=41948
# [PASS2 200/299] n_scheda=41952
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=116 pass2_still_not_found=84 | SBN=94 OL=12 LoC=10 IA=0
# [PASS2 201/299] n_scheda=41954
# [PASS2 202/299] n_scheda=41955
# [PASS2 203/299] n_scheda=41956
# [PASS2 204/299] n_scheda=41959
# [PASS2 205/299] n_scheda=41961
# [PASS2 206/299] n_scheda=41962
# [PASS2 207/299] n_scheda=41966
# [PASS2 208/299] n_scheda=41967
# [PASS2 209/299] n_scheda=41971
# [PASS2 210/299] n_scheda=41973
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=126 pass2_still_not_found=84 | SBN=103 OL=13 LoC=10 IA=0
# [PASS2 211/299] n_scheda=41978
# [PASS2 212/299] n_scheda=41981
# [PASS2 213/299] n_scheda=41983
# [PASS2 214/299] n_scheda=41986
# [PASS2 215/299] n_scheda=41988
# [PASS2 216/299] n_scheda=41991
# [PASS2 217/299] n_scheda=41992
# [PASS2 218/299] n_scheda=41994
# [PASS2 219/299] n_scheda=41999
# [PASS2 220/299] n_scheda=42001
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=134 pass2_still_not_found=86 | SBN=109 OL=15 LoC=10 IA=0
# [PASS2 221/299] n_scheda=42003
# [PASS2 222/299] n_scheda=42004
# [PASS2 223/299] n_scheda=42005
# [PASS2 224/299] n_scheda=42006
# [PASS2 225/299] n_scheda=42007
# [PASS2 226/299] n_scheda=42008
# [PASS2 227/299] n_scheda=42009
# [PASS2 228/299] n_scheda=42012
# [PASS2 229/299] n_scheda=42013
# [PASS2 230/299] n_scheda=42017
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=143 pass2_still_not_found=87 | SBN=116 OL=17 LoC=10 IA=0
# [PASS2 231/299] n_scheda=42029
# [PASS2 232/299] n_scheda=42036
# [PASS2 233/299] n_scheda=42047
# [PASS2 234/299] n_scheda=42049
# [PASS2 235/299] n_scheda=42051
# [PASS2 236/299] n_scheda=42052
# [PASS2 237/299] n_scheda=42053
# [PASS2 238/299] n_scheda=42055
# [PASS2 239/299] n_scheda=42057
# [PASS2 240/299] n_scheda=42059
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=149 pass2_still_not_found=91 | SBN=121 OL=17 LoC=11 IA=0
# [PASS2 241/299] n_scheda=42063
# [PASS2 242/299] n_scheda=42065
# [PASS2 243/299] n_scheda=42068
# [PASS2 244/299] n_scheda=42069
# [PASS2 245/299] n_scheda=42073
# [PASS2 246/299] n_scheda=42075
# [PASS2 247/299] n_scheda=42082
# [PASS2 248/299] n_scheda=42084
# [PASS2 249/299] n_scheda=42093
# [PASS2 250/299] n_scheda=42094
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=156 pass2_still_not_found=94 | SBN=128 OL=17 LoC=11 IA=0
# [PASS2 251/299] n_scheda=42097
# [PASS2 252/299] n_scheda=42098
# [PASS2 253/299] n_scheda=42100
# [PASS2 254/299] n_scheda=42101
# [PASS2 255/299] n_scheda=42102
# [PASS2 256/299] n_scheda=42103
# [PASS2 257/299] n_scheda=42104
# [PASS2 258/299] n_scheda=42105
# [PASS2 259/299] n_scheda=42106
# [PASS2 260/299] n_scheda=42108
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=165 pass2_still_not_found=95 | SBN=135 OL=19 LoC=11 IA=0
# [PASS2 261/299] n_scheda=42109
# [PASS2 262/299] n_scheda=42112
# [PASS2 263/299] n_scheda=42113
# [PASS2 264/299] n_scheda=42114
# [PASS2 265/299] n_scheda=42115
# [PASS2 266/299] n_scheda=42116
# [PASS2 267/299] n_scheda=42117
# [PASS2 268/299] n_scheda=42120
# [PASS2 269/299] n_scheda=42122
# [PASS2 270/299] n_scheda=42123
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=173 pass2_still_not_found=97 | SBN=143 OL=19 LoC=11 IA=0
# [PASS2 271/299] n_scheda=42125
# [PASS2 272/299] n_scheda=42126
# [PASS2 273/299] n_scheda=42127
# [PASS2 274/299] n_scheda=42128
# [PASS2 275/299] n_scheda=42129
# [PASS2 276/299] n_scheda=42132
# [PASS2 277/299] n_scheda=42133
# [PASS2 278/299] n_scheda=42134
# [PASS2 279/299] n_scheda=42135
# [PASS2 280/299] n_scheda=42136
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=178 pass2_still_not_found=102 | SBN=148 OL=19 LoC=11 IA=0
# [PASS2 281/299] n_scheda=42137
# [PASS2 282/299] n_scheda=42138
# [PASS2 283/299] n_scheda=42149
# [PASS2 284/299] n_scheda=42150
# [PASS2 285/299] n_scheda=42156
# [PASS2 286/299] n_scheda=42157
# [PASS2 287/299] n_scheda=42158
# [PASS2 288/299] n_scheda=42159
# [PASS2 289/299] n_scheda=42161
# [PASS2 290/299] n_scheda=42164
# Checkpoint PASS2: biblio_longform_all_records_enriched.csv | pass2_found=186 pass2_still_not_found=104 | SBN=155 OL=19 LoC=12 IA=0
# [PASS2 291/299] n_scheda=42167
# [PASS2 292/299] n_scheda=42168
# [PASS2 293/299] n_scheda=42169
# [PASS2 294/299] n_scheda=42170
# [PASS2 295/299] n_scheda=42171
# [PASS2 296/299] n_scheda=42172
# [PASS2 297/299] n_scheda=42175
# [PASS2 298/299] n_scheda=42182
# [PASS2 299/299] n_scheda=42184
# PASS2 completed. LONG: biblio_longform_all_records_enriched.csv | pass2_found=192 pass2_still_not_found=107 | SBN=161 OL=19 LoC=12 IA=0
# WIDE creato: biblio_wide_records_enriched.csv | righe=1000 colonne=29
