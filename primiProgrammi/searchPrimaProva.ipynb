# %%
from ol_ia_search import unified_search, to_dataframe

# %%
hits = unified_search("Benedetto Croce", "Filosofia della pratica", year_range=(1890, 1930), language="ita")

# %%
hits
# Out:
# [UnifiedHit(source='openlibrary', author='Benedetto Croce', title='Filosofia della pratica', year=1909, language='ita', identifier='/works/OL42721585W', url='https://openlibrary.org/works/OL42721585W', score=1.0, extra={'edition_count': 1, 'publisher': [], 'isbn': [], 'ia_ids': [], 'oclc_numbers': [], 'lccn': []}),
#  UnifiedHit(source='openlibrary', author='Benedetto Croce', title='Filosofia della pratica', year=1915, language='ita', identifier='/works/OL1107871W', url='https://openlibrary.org/works/OL1107871W', score=1.0, extra={'edition_count': 4, 'publisher': [], 'isbn': [], 'ia_ids': ['filosofiadellapr00croc'], 'oclc_numbers': [], 'lccn': []}),
# ...

# %%
hits2 = unified_search("Benedetto Croce", "Filosofia della pratica")

# %%
hits2
# Out:
# [UnifiedHit(source='openlibrary', author='Benedetto Croce', title='Filosofia della pratica', year=1909, language='ita', identifier='/works/OL42721585W', url='https://openlibrary.org/works/OL42721585W', score=1.0, extra={'edition_count': 1, 'publisher': [], 'isbn': [], 'ia_ids': [], 'oclc_numbers': [], 'lccn': []}),
#  UnifiedHit(source='openlibrary', author='Benedetto Croce', title='Filosofia della pratica', year=1915, language='ita', identifier='/works/OL1107871W', url='https://openlibrary.org/works/OL1107871W', score=1.0, extra={'edition_count': 4, 'publisher': [], 'isbn': [], 'ia_ids': ['filosofiadellapr00croc'], 'oclc_numbers': [], 'lccn': []}),
# ...

# %%
df = to_dataframe(hits)
df
# Out:
#         source  score           author  \
# 0  openlibrary   1.00  Benedetto Croce
# 1  openlibrary   1.00  Benedetto Croce
# 2  openlibrary   1.00  Benedetto Croce
# 3  openlibrary   1.00  Benedetto Croce
# 4  openlibrary   1.00  Benedetto Croce
# 5  openlibrary   0.65  Croce Benedetto
#
#                                          title  year language  \
# 0                      Filosofia della pratica  1909      ita
# 1                      Filosofia della pratica  1915      ita
# 2                      Filosofia della pratica  1915      ita
# 3                      Filosofia della pratica  1932      ita
# 4                      Filosofia della pratica  1950      ita
# 5  Filosofia Della Pratica, Economica Ed Etica  2022      ita
#
#            identifier                                 record_url   pdf  epub  \
# 0  /works/OL42721585W  https://openlibrary.org/works/OL42721585W  None  None
# 1   /works/OL1107871W   https://openlibrary.org/works/OL1107871W  None  None
# ...
