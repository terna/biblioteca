# %%
#da https://chatgpt.com/share/6959abcc-287c-8013-a2a7-8b7190ae7fd2

#setup e configurazione

import os, re, json, time, math
from difflib import SequenceMatcher
from urllib.parse import quote_plus

import pandas as pd
import requests

INPUT_CSV  = "biblio_longform_all_records.csv"
OUTPUT_CSV = "biblio_longform_all_records_enriched.csv"
PROGRESS_JSON = "biblio_enrich_progress.json"

# --- Networking ---
SESSION = requests.Session()
SESSION.headers.update({
    "User-Agent": "biblio-enricher/1.0 (academic research; contact: pietro.terna@unito.it)"
})
TIMEOUT = 30
SLEEP_BETWEEN_CALLS = 0.25  # prudenziale per non martellare i servizi

# --- Matching ---
TOPK_PER_SOURCE = 5

def _sleep():
    time.sleep(SLEEP_BETWEEN_CALLS)

def norm(s: str) -> str:
    if s is None:
        return ""
    s = str(s).strip().lower()
    s = re.sub(r"\s+", " ", s)
    s = re.sub(r"[“”\"'’`]", "", s)
    s = re.sub(r"[^0-9a-zàèéìòùçäëïöüßñ \-:/]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

def sim(a: str, b: str) -> float:
    a, b = norm(a), norm(b)
    if not a or not b:
        return 0.0
    return SequenceMatcher(None, a, b).ratio()

def extract_year(s: str):
    if not s:
        return None
    m = re.search(r"(1[5-9]\d{2}|20\d{2})", str(s))
    return int(m.group(1)) if m else None

def safe_get(d, *keys, default=None):
    cur = d
    for k in keys:
        if isinstance(cur, dict) and k in cur:
            cur = cur[k]
        else:
            return default
    return cur

def load_progress():
    if os.path.exists(PROGRESS_JSON):
        with open(PROGRESS_JSON, "r", encoding="utf-8") as f:
            return json.load(f)
    return {"done_n_scheda": [], "last_index": 0}

def save_progress(prog):
    with open(PROGRESS_JSON, "w", encoding="utf-8") as f:
        json.dump(prog, f, ensure_ascii=False, indent=2)

print("Setup OK.")
# Out:
# Setup OK.

# %%
#lettura longform e raggruppamento “libro per libro”

df = pd.read_csv(INPUT_CSV)

# Sanity check
assert set(df.columns) >= {"n_scheda","campo","valore"}, "CSV non nel formato atteso (n_scheda,campo,valore)."

# Raggruppo per scheda (libro)
groups = list(df.groupby("n_scheda", sort=True))
n_books = len(groups)

print("Righe:", len(df), " | Libri (n_scheda distinti):", n_books)
print("Esempio campi:", sorted(df["campo"].unique())[:20])
# Out:
# Righe: 11477  | Libri (n_scheda distinti): 1000
# Esempio campi: ['autore', 'cod_isbn', 'cod_sez', 'collabor', 'collezion', 'data_pub', 'editore', 'edizione', 'formato', 'luogo_pub', 'n_s_sez', 'n_scheda', 'note_sp', 'pagine', 'soggetto', 'titolo']

# %%
#estrazione dati “di input” (titolo/autore/anno/ISBN ecc.)

def book_input_from_group(g: pd.DataFrame) -> dict:
    # prende la "migliore" occorrenza per campo
    # (se ci sono ripetizioni, tiene la prima non vuota)
    rec = {"n_scheda": int(g["n_scheda"].iloc[0])}

    def first_value(field):
        vals = g.loc[g["campo"] == field, "valore"].dropna().astype(str).tolist()
        vals = [v.strip() for v in vals if v.strip() and v.strip().lower() != "nan"]
        return vals[0] if vals else ""

    rec["autore"] = first_value("autore")
    rec["titolo"] = first_value("titolo")
    rec["editore"] = first_value("editore")
    rec["luogo_pub"] = first_value("luogo_pub")
    rec["data_pub"] = first_value("data_pub")
    rec["cod_isbn"] = first_value("cod_isbn")

    rec["year"] = extract_year(rec["data_pub"]) or extract_year(rec["titolo"])
    # query “compatta” per motori che accettano full text
    q_parts = [rec["titolo"], rec["autore"], str(rec["year"]) if rec["year"] else ""]
    rec["q"] = " ".join([p for p in q_parts if p]).strip()

    return rec

# preview di un libro
sample = book_input_from_group(groups[0][1])
sample
# Out:
# {'n_scheda': 41186,
#  'autore': 'CARINGTON, WHATELY',
#  'titolo': '',
#  'editore': 'ASTROLABIO',
#  'luogo_pub': 'ROMA',
#  'data_pub': 'COPYRIGHT 1972',
#  'cod_isbn': '',
#  'year': 1972,
#  'q': 'CARINGTON, WHATELY 1972'}

# %%
#client OPAC SBN (opacmobilegw)

def sbn_search(q: str, rows=TOPK_PER_SOURCE):
    # endpoint app mobile (non ufficiale)
    url = f"https://opac.sbn.it/opacmobilegw/search.json?any={quote_plus(q)}&type=0&start=0&rows={rows}"
    r = SESSION.get(url, timeout=TIMEOUT)
    _sleep()
    r.raise_for_status()
    return r.json()

def sbn_full(bid: str):
    # bid in forma "IT\\ICCU\\..." nella search; in URL bisogna passarlo con backslash singoli
    url = f"https://opac.sbn.it/opacmobilegw/full.json?bid={quote_plus(bid)}"
    r = SESSION.get(url, timeout=TIMEOUT)
    _sleep()
    r.raise_for_status()
    return r.json()

def sbn_candidates(book: dict):
    if not book["q"]:
        return []
    try:
        js = sbn_search(book["q"])
    except Exception:
        return []

    hits = js.get("records") or js.get("record") or js.get("results") or js.get("docs") or js.get("elenco") or js.get("items")
    # in molte risposte reali l'elenco è in chiave "records"; ma manteniamo fallback
    if hits is None:
        hits = js.get("records", [])

    if not isinstance(hits, list):
        hits = []

    cands = []
    for h in hits[:TOPK_PER_SOURCE]:
        title = h.get("titolo") or ""
        auth  = h.get("autorePrincipale") or ""
        pub   = h.get("pubblicazione") or ""
        bid   = h.get("codiceIdentificativo") or ""

        score = 0.70 * sim(book["titolo"], title) + 0.30 * sim(book["autore"], auth)
        by = extract_year(pub) or None
        if book.get("year") and by and abs(book["year"] - by) <= 1:
            score += 0.05

        cands.append({"source":"OPAC SBN", "score":score, "title":title, "author":auth, "pub":pub, "bid":bid, "raw":h})

    # arricchisco col full.json solo per i migliori 2 (per ridurre traffico)
    cands = sorted(cands, key=lambda x: x["score"], reverse=True)
    for c in cands[:2]:
        if c.get("bid"):
            try:
                full = sbn_full(c["bid"])
                c["full"] = full
            except Exception:
                c["full"] = None
    return cands

# %%
#Open Library

def ol_search(title: str, author: str, rows=TOPK_PER_SOURCE):
    # Search API ufficiale
    params = {"title": title or "", "author": author or "", "limit": rows}
    r = SESSION.get("https://openlibrary.org/search.json", params=params, timeout=TIMEOUT)
    _sleep()
    r.raise_for_status()
    return r.json()

def ol_candidates(book: dict):
    if not (book["titolo"] or book["autore"]):
        return []
    try:
        js = ol_search(book["titolo"], book["autore"])
    except Exception:
        return []
    docs = js.get("docs", [])[:TOPK_PER_SOURCE]
    cands = []
    for d in docs:
        title = d.get("title") or ""
        auth  = (d.get("author_name") or [""])[0]
        year  = d.get("first_publish_year")
        score = 0.70 * sim(book["titolo"], title) + 0.30 * sim(book["autore"], auth)
        if book.get("year") and year and abs(book["year"] - int(year)) <= 1:
            score += 0.05
        cands.append({"source":"Open Library", "score":score, "title":title, "author":auth, "year":year, "raw":d})
    return sorted(cands, key=lambda x: x["score"], reverse=True)

# %%
#Library of Congress (loc.gov JSON)

def loc_search(q: str, rows=TOPK_PER_SOURCE):
    # endpoint "books" su loc.gov
    params = {"fo": "json", "q": q, "c": rows}
    r = SESSION.get("https://www.loc.gov/books/", params=params, timeout=TIMEOUT)
    _sleep()
    r.raise_for_status()
    return r.json()

def loc_candidates(book: dict):
    if not book["q"]:
        return []
    try:
        js = loc_search(book["q"])
    except Exception:
        return []
    results = js.get("results", [])[:TOPK_PER_SOURCE]
    cands = []
    for it in results:
        title = it.get("title") or ""
        # loc.gov spesso mette autore in 'contributor' o 'creator'
        auth_list = it.get("contributor") or it.get("creator") or []
        auth = auth_list[0] if isinstance(auth_list, list) and auth_list else ""
        date = it.get("date") or ""
        year = extract_year(date)

        score = 0.70 * sim(book["titolo"], title) + 0.30 * sim(book["autore"], auth)
        if book.get("year") and year and abs(book["year"] - year) <= 1:
            score += 0.05

        cands.append({"source":"Library of Congress", "score":score, "title":title, "author":auth, "date":date, "id":it.get("id"), "raw":it})
    return sorted(cands, key=lambda x: x["score"], reverse=True)

# %%
#Internet Archive (advancedsearch + metadata)

def ia_advanced_search(title: str, author: str, rows=TOPK_PER_SOURCE):
    # query in sintassi IA (Elastic/Lucene-like)
    # limitiamo ai testi (dove possibile) per ridurre rumore
    q = []
    if title:
        q.append(f'title:("{title}")')
    if author:
        q.append(f'creator:("{author}")')
    q.append('(mediatype:texts OR collection:opensource_texts)')
    query = " AND ".join(q)

    params = {
        "q": query,
        "fl[]": ["identifier", "title", "creator", "date", "publisher", "language"],
        "rows": rows,
        "page": 1,
        "output": "json"
    }
    r = SESSION.get("https://archive.org/advancedsearch.php", params=params, timeout=TIMEOUT)
    _sleep()
    r.raise_for_status()
    return r.json()

def ia_metadata(identifier: str):
    r = SESSION.get(f"https://archive.org/metadata/{identifier}", timeout=TIMEOUT)
    _sleep()
    r.raise_for_status()
    return r.json()

def ia_candidates(book: dict):
    if not (book["titolo"] or book["autore"]):
        return []
    try:
        js = ia_advanced_search(book["titolo"], book["autore"])
    except Exception:
        return []

    docs = safe_get(js, "response", "docs", default=[])[:TOPK_PER_SOURCE]
    cands = []
    for d in docs:
        title = d.get("title") or ""
        creator = d.get("creator")
        auth = creator[0] if isinstance(creator, list) and creator else (creator or "")
        year = extract_year(d.get("date"))

        score = 0.70 * sim(book["titolo"], title) + 0.30 * sim(book["autore"], auth)
        if book.get("year") and year and abs(book["year"] - year) <= 1:
            score += 0.05

        cands.append({"source":"Internet Archive", "score":score, "title":title, "author":auth, "year":year,
                      "identifier": d.get("identifier"), "raw":d})

    cands = sorted(cands, key=lambda x: x["score"], reverse=True)

    # metadata completa solo per il migliore
    if cands and cands[0].get("identifier"):
        try:
            cands[0]["full"] = ia_metadata(cands[0]["identifier"])
        except Exception:
            cands[0]["full"] = None

    return cands

# %%
#normalizzazione output “campi standard” (ext_*)

STANDARD_FIELDS = [
    "ext_source",
    "ext_match_score",
    "ext_title",
    "ext_author",
    "ext_year",
    "ext_publisher",
    "ext_place",
    "ext_language",
    "ext_physical_desc",
    "ext_identifiers",
    "ext_notes",
    "ext_url"
]

def pack_identifiers(d: dict) -> str:
    # stringa JSON compatta, così non perdiamo struttura
    return json.dumps(d, ensure_ascii=False)

def from_sbn(best: dict) -> dict:
    full = best.get("full") or {}
    out = {
        "ext_source": "OPAC SBN",
        "ext_match_score": f"{best.get('score',0):.3f}",
        "ext_title": full.get("titolo") or best.get("title") or "",
        "ext_author": full.get("autorePrincipale") or best.get("author") or "",
        "ext_year": str(extract_year(full.get("pubblicazione")) or extract_year(best.get("pub")) or "") or "",
        "ext_publisher": "",  # spesso è dentro 'pubblicazione' non splittata
        "ext_place": "",
        "ext_language": full.get("linguaPubblicazione") or "",
        "ext_physical_desc": full.get("descrizioneFisica") or "",
        "ext_identifiers": pack_identifiers({"bid": best.get("bid")}),
        "ext_notes": " | ".join(full.get("note") or []) if isinstance(full.get("note"), list) else (full.get("note") or ""),
        "ext_url": f"https://opac.sbn.it/opacmobilegw/full.json?bid={quote_plus(best.get('bid',''))}" if best.get("bid") else ""
    }
    return out

def from_ol(best: dict) -> dict:
    d = best.get("raw") or {}
    identifiers = {}
    for k in ["isbn", "oclc", "lccn"]:
        if k in d and d[k]:
            identifiers[k] = d[k][:10] if isinstance(d[k], list) else d[k]
    out = {
        "ext_source": "Open Library",
        "ext_match_score": f"{best.get('score',0):.3f}",
        "ext_title": best.get("title") or "",
        "ext_author": best.get("author") or "",
        "ext_year": str(best.get("year") or ""),
        "ext_publisher": (d.get("publisher") or [""])[0] if isinstance(d.get("publisher"), list) else (d.get("publisher") or ""),
        "ext_place": (d.get("publish_place") or [""])[0] if isinstance(d.get("publish_place"), list) else (d.get("publish_place") or ""),
        "ext_language": (d.get("language") or [""])[0] if isinstance(d.get("language"), list) else (d.get("language") or ""),
        "ext_physical_desc": "",
        "ext_identifiers": pack_identifiers(identifiers),
        "ext_notes": "",
        "ext_url": f"https://openlibrary.org{d.get('key','')}" if d.get("key") else ""
    }
    return out

def from_loc(best: dict) -> dict:
    d = best.get("raw") or {}
    out = {
        "ext_source": "Library of Congress",
        "ext_match_score": f"{best.get('score',0):.3f}",
        "ext_title": best.get("title") or "",
        "ext_author": best.get("author") or "",
        "ext_year": str(extract_year(best.get("date") or "") or ""),
        "ext_publisher": "",  # spesso richiede item detail; qui lo teniamo vuoto
        "ext_place": "",
        "ext_language": "",
        "ext_physical_desc": "",
        "ext_identifiers": pack_identifiers({"loc_id": best.get("id")}),
        "ext_notes": "",
        "ext_url": best.get("id") or ""
    }
    return out

def from_ia(best: dict) -> dict:
    d = best.get("raw") or {}
    full = best.get("full") or {}
    md = full.get("metadata") or {}

    # md può avere liste o stringhe
    def md1(k):
        v = md.get(k, "")
        if isinstance(v, list):
            return v[0] if v else ""
        return v or ""

    identifiers = {"identifier": best.get("identifier")}
    out = {
        "ext_source": "Internet Archive",
        "ext_match_score": f"{best.get('score',0):.3f}",
        "ext_title": md1("title") or best.get("title") or "",
        "ext_author": md1("creator") or best.get("author") or "",
        "ext_year": str(extract_year(md1("date")) or best.get("year") or ""),
        "ext_publisher": md1("publisher"),
        "ext_place": md1("publishplace"),
        "ext_language": md1("language"),
        "ext_physical_desc": md1("description"),
        "ext_identifiers": pack_identifiers(identifiers),
        "ext_notes": md1("notes"),
        "ext_url": f"https://archive.org/details/{best.get('identifier')}" if best.get("identifier") else ""
    }
    return out

def choose_best_candidate(book: dict):
    # cascata: SBN -> OL -> LOC -> IA
    # ma se SBN non supera soglia minima, prosegui
    MIN_SCORE = 0.4 #0.55

    sbn = sbn_candidates(book)
    if sbn and sbn[0]["score"] >= MIN_SCORE:
        return sbn[0], from_sbn(sbn[0])

    ol = ol_candidates(book)
    if ol and ol[0]["score"] >= MIN_SCORE:
        return ol[0], from_ol(ol[0])

    loc = loc_candidates(book)
    if loc and loc[0]["score"] >= MIN_SCORE:
        return loc[0], from_loc(loc[0])

    ia = ia_candidates(book)
    if ia and ia[0]["score"] >= MIN_SCORE:
        return ia[0], from_ia(ia[0])

    return None, {"ext_source":"NOT_FOUND", "ext_match_score":"0.000",
                  "ext_title":"", "ext_author":"", "ext_year":"",
                  "ext_publisher":"", "ext_place":"", "ext_language":"",
                  "ext_physical_desc":"", "ext_identifiers":pack_identifiers({}),
                  "ext_notes":"", "ext_url":""}

# %%
#loop “uno per uno”, con stampa del numero libro (1..N) e salvataggio incrementale

prog = load_progress()
done = set(prog.get("done_n_scheda", []))

out_rows = []
# Se esiste già un output, lo carico e ci appendo (ripartenza)
if os.path.exists(OUTPUT_CSV):
    existing = pd.read_csv(OUTPUT_CSV)
    out_rows = existing.to_dict(orient="records")
    print("Ripartenza: output esistente caricato:", len(existing), "righe")
else:
    out_rows = df.to_dict(orient="records")

# indicizzazione rapida: per ogni n_scheda, quante righe originali già presenti in out_rows?
# (out_rows contiene già originali; noi aggiungiamo solo le righe ext_*; per evitare doppioni controlliamo)
already_ext = set()
for r in out_rows:
    if str(r.get("campo","")).startswith("ext_"):
        already_ext.add((int(r["n_scheda"]), r["campo"]))

for i, (n_scheda, g) in enumerate(groups, start=1):
    CURRENT_BOOK_NUMBER = i
    print(f"[{CURRENT_BOOK_NUMBER}/{n_books}] n_scheda={n_scheda}")

    if int(n_scheda) in done:
        # già processato: salto
        continue

    book = book_input_from_group(g)
    cand, ext = choose_best_candidate(book)

    # aggiungo righe longform ext_* in fondo alla scheda (append al dataset)
    for k in STANDARD_FIELDS:
        if (int(n_scheda), k) in already_ext:
            continue
        out_rows.append({"n_scheda": int(n_scheda), "campo": k, "valore": ext.get(k, "")})
        already_ext.add((int(n_scheda), k))

    # checkpoint
    done.add(int(n_scheda))
    prog["done_n_scheda"] = sorted(list(done))
    prog["last_index"] = i
    save_progress(prog)

    # scrittura su disco ogni 5 libri (riduci rischio di perdere lavoro)
    if i % 5 == 0:
        pd.DataFrame(out_rows).to_csv(OUTPUT_CSV, index=False)
        print("Checkpoint scritto:", OUTPUT_CSV)

# scrittura finale
pd.DataFrame(out_rows).to_csv(OUTPUT_CSV, index=False)
print("Completato. Output:", OUTPUT_CSV)
# Out:
# Ripartenza: output esistente caricato: 12377 righe
# [1/1000] n_scheda=41186
# [2/1000] n_scheda=41187
# [3/1000] n_scheda=41188
# [4/1000] n_scheda=41189
# [5/1000] n_scheda=41190
# [6/1000] n_scheda=41191
# [7/1000] n_scheda=41192
# [8/1000] n_scheda=41193
# [9/1000] n_scheda=41194
# [10/1000] n_scheda=41195
# [11/1000] n_scheda=41196
# [12/1000] n_scheda=41197
# [13/1000] n_scheda=41198
# [14/1000] n_scheda=41199
# [15/1000] n_scheda=41200
# [16/1000] n_scheda=41201
# [17/1000] n_scheda=41202
# [18/1000] n_scheda=41203
# [19/1000] n_scheda=41204
# [20/1000] n_scheda=41205
# [21/1000] n_scheda=41206
# [22/1000] n_scheda=41207
# [23/1000] n_scheda=41208
# [24/1000] n_scheda=41209
# [25/1000] n_scheda=41210
# [26/1000] n_scheda=41211
# [27/1000] n_scheda=41212
# [28/1000] n_scheda=41213
# [29/1000] n_scheda=41214
# [30/1000] n_scheda=41215
# [31/1000] n_scheda=41216
# [32/1000] n_scheda=41217
# [33/1000] n_scheda=41218
# [34/1000] n_scheda=41219
# [35/1000] n_scheda=41220
# [36/1000] n_scheda=41221
# [37/1000] n_scheda=41222
# [38/1000] n_scheda=41223
# [39/1000] n_scheda=41224
# [40/1000] n_scheda=41225
# [41/1000] n_scheda=41226
# [42/1000] n_scheda=41227
# [43/1000] n_scheda=41228
# [44/1000] n_scheda=41229
# [45/1000] n_scheda=41230
# [46/1000] n_scheda=41231
# [47/1000] n_scheda=41232
# [48/1000] n_scheda=41233
# [49/1000] n_scheda=41234
# [50/1000] n_scheda=41235
# [51/1000] n_scheda=41236
# [52/1000] n_scheda=41237
# [53/1000] n_scheda=41238
# [54/1000] n_scheda=41239
# [55/1000] n_scheda=41240
# [56/1000] n_scheda=41241
# [57/1000] n_scheda=41242
# [58/1000] n_scheda=41243
# [59/1000] n_scheda=41244
# [60/1000] n_scheda=41245
# [61/1000] n_scheda=41246
# [62/1000] n_scheda=41247
# [63/1000] n_scheda=41248
# [64/1000] n_scheda=41249
# [65/1000] n_scheda=41250
# [66/1000] n_scheda=41251
# [67/1000] n_scheda=41252
# [68/1000] n_scheda=41253
# [69/1000] n_scheda=41254
# [70/1000] n_scheda=41255
# [71/1000] n_scheda=41256
# [72/1000] n_scheda=41257
# [73/1000] n_scheda=41258
# [74/1000] n_scheda=41259
# [75/1000] n_scheda=41260
# [76/1000] n_scheda=41261
# [77/1000] n_scheda=41262
# [78/1000] n_scheda=41263
# [79/1000] n_scheda=41264
# [80/1000] n_scheda=41265
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [81/1000] n_scheda=41266
# [82/1000] n_scheda=41267
# [83/1000] n_scheda=41268
# [84/1000] n_scheda=41269
# [85/1000] n_scheda=41270
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [86/1000] n_scheda=41271
# [87/1000] n_scheda=41272
# [88/1000] n_scheda=41273
# [89/1000] n_scheda=41274
# [90/1000] n_scheda=41275
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [91/1000] n_scheda=41276
# [92/1000] n_scheda=41277
# [93/1000] n_scheda=41278
# [94/1000] n_scheda=41279
# [95/1000] n_scheda=41280
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [96/1000] n_scheda=41281
# [97/1000] n_scheda=41282
# [98/1000] n_scheda=41283
# [99/1000] n_scheda=41284
# [100/1000] n_scheda=41285
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [101/1000] n_scheda=41286
# [102/1000] n_scheda=41287
# [103/1000] n_scheda=41288
# [104/1000] n_scheda=41289
# [105/1000] n_scheda=41290
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [106/1000] n_scheda=41291
# [107/1000] n_scheda=41292
# [108/1000] n_scheda=41293
# [109/1000] n_scheda=41294
# [110/1000] n_scheda=41295
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [111/1000] n_scheda=41296
# [112/1000] n_scheda=41297
# [113/1000] n_scheda=41298
# [114/1000] n_scheda=41299
# [115/1000] n_scheda=41300
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [116/1000] n_scheda=41301
# [117/1000] n_scheda=41302
# [118/1000] n_scheda=41303
# [119/1000] n_scheda=41304
# [120/1000] n_scheda=41305
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [121/1000] n_scheda=41306
# [122/1000] n_scheda=41307
# [123/1000] n_scheda=41308
# [124/1000] n_scheda=41309
# [125/1000] n_scheda=41310
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [126/1000] n_scheda=41311
# [127/1000] n_scheda=41312
# [128/1000] n_scheda=41313
# [129/1000] n_scheda=41314
# [130/1000] n_scheda=41315
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [131/1000] n_scheda=41316
# [132/1000] n_scheda=41317
# [133/1000] n_scheda=41318
# [134/1000] n_scheda=41319
# [135/1000] n_scheda=41320
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [136/1000] n_scheda=41321
# [137/1000] n_scheda=41322
# [138/1000] n_scheda=41323
# [139/1000] n_scheda=41324
# [140/1000] n_scheda=41325
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [141/1000] n_scheda=41326
# [142/1000] n_scheda=41327
# [143/1000] n_scheda=41328
# [144/1000] n_scheda=41329
# [145/1000] n_scheda=41330
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [146/1000] n_scheda=41331
# [147/1000] n_scheda=41332
# [148/1000] n_scheda=41333
# [149/1000] n_scheda=41334
# [150/1000] n_scheda=41335
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [151/1000] n_scheda=41336
# [152/1000] n_scheda=41337
# [153/1000] n_scheda=41338
# [154/1000] n_scheda=41339
# [155/1000] n_scheda=41340
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [156/1000] n_scheda=41341
# [157/1000] n_scheda=41342
# [158/1000] n_scheda=41343
# [159/1000] n_scheda=41344
# [160/1000] n_scheda=41345
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [161/1000] n_scheda=41346
# [162/1000] n_scheda=41347
# [163/1000] n_scheda=41348
# [164/1000] n_scheda=41349
# [165/1000] n_scheda=41350
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [166/1000] n_scheda=41351
# [167/1000] n_scheda=41352
# [168/1000] n_scheda=41353
# [169/1000] n_scheda=41354
# [170/1000] n_scheda=41355
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [171/1000] n_scheda=41356
# [172/1000] n_scheda=41357
# [173/1000] n_scheda=41358
# [174/1000] n_scheda=41359
# [175/1000] n_scheda=41360
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [176/1000] n_scheda=41361
# [177/1000] n_scheda=41362
# [178/1000] n_scheda=41363
# [179/1000] n_scheda=41364
# [180/1000] n_scheda=41365
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [181/1000] n_scheda=41366
# [182/1000] n_scheda=41367
# [183/1000] n_scheda=41368
# [184/1000] n_scheda=41369
# [185/1000] n_scheda=41370
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [186/1000] n_scheda=41371
# [187/1000] n_scheda=41372
# [188/1000] n_scheda=41373
# [189/1000] n_scheda=41374
# [190/1000] n_scheda=41375
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [191/1000] n_scheda=41376
# [192/1000] n_scheda=41377
# [193/1000] n_scheda=41378
# [194/1000] n_scheda=41379
# [195/1000] n_scheda=41380
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [196/1000] n_scheda=41381
# [197/1000] n_scheda=41382
# [198/1000] n_scheda=41383
# [199/1000] n_scheda=41384
# [200/1000] n_scheda=41385
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [201/1000] n_scheda=41386
# [202/1000] n_scheda=41387
# [203/1000] n_scheda=41388
# [204/1000] n_scheda=41389
# [205/1000] n_scheda=41390
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [206/1000] n_scheda=41391
# [207/1000] n_scheda=41392
# [208/1000] n_scheda=41393
# [209/1000] n_scheda=41394
# [210/1000] n_scheda=41395
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [211/1000] n_scheda=41396
# [212/1000] n_scheda=41397
# [213/1000] n_scheda=41398
# [214/1000] n_scheda=41399
# [215/1000] n_scheda=41400
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [216/1000] n_scheda=41401
# [217/1000] n_scheda=41402
# [218/1000] n_scheda=41403
# [219/1000] n_scheda=41404
# [220/1000] n_scheda=41405
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [221/1000] n_scheda=41406
# [222/1000] n_scheda=41407
# [223/1000] n_scheda=41408
# [224/1000] n_scheda=41409
# [225/1000] n_scheda=41410
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [226/1000] n_scheda=41411
# [227/1000] n_scheda=41412
# [228/1000] n_scheda=41413
# [229/1000] n_scheda=41414
# [230/1000] n_scheda=41415
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [231/1000] n_scheda=41416
# [232/1000] n_scheda=41417
# [233/1000] n_scheda=41418
# [234/1000] n_scheda=41419
# [235/1000] n_scheda=41420
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [236/1000] n_scheda=41421
# [237/1000] n_scheda=41422
# [238/1000] n_scheda=41423
# [239/1000] n_scheda=41424
# [240/1000] n_scheda=41425
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [241/1000] n_scheda=41426
# [242/1000] n_scheda=41427
# [243/1000] n_scheda=41428
# [244/1000] n_scheda=41429
# [245/1000] n_scheda=41430
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [246/1000] n_scheda=41431
# [247/1000] n_scheda=41432
# [248/1000] n_scheda=41433
# [249/1000] n_scheda=41434
# [250/1000] n_scheda=41435
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [251/1000] n_scheda=41436
# [252/1000] n_scheda=41437
# [253/1000] n_scheda=41438
# [254/1000] n_scheda=41439
# [255/1000] n_scheda=41440
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [256/1000] n_scheda=41441
# [257/1000] n_scheda=41442
# [258/1000] n_scheda=41443
# [259/1000] n_scheda=41444
# [260/1000] n_scheda=41445
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [261/1000] n_scheda=41446
# [262/1000] n_scheda=41447
# [263/1000] n_scheda=41448
# [264/1000] n_scheda=41449
# [265/1000] n_scheda=41450
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [266/1000] n_scheda=41451
# [267/1000] n_scheda=41452
# [268/1000] n_scheda=41453
# [269/1000] n_scheda=41454
# [270/1000] n_scheda=41455
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [271/1000] n_scheda=41456
# [272/1000] n_scheda=41457
# [273/1000] n_scheda=41458
# [274/1000] n_scheda=41459
# [275/1000] n_scheda=41460
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [276/1000] n_scheda=41461
# [277/1000] n_scheda=41462
# [278/1000] n_scheda=41463
# [279/1000] n_scheda=41464
# [280/1000] n_scheda=41465
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [281/1000] n_scheda=41466
# [282/1000] n_scheda=41467
# [283/1000] n_scheda=41468
# [284/1000] n_scheda=41469
# [285/1000] n_scheda=41470
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [286/1000] n_scheda=41471
# [287/1000] n_scheda=41472
# [288/1000] n_scheda=41473
# [289/1000] n_scheda=41474
# [290/1000] n_scheda=41475
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [291/1000] n_scheda=41476
# [292/1000] n_scheda=41477
# [293/1000] n_scheda=41478
# [294/1000] n_scheda=41479
# [295/1000] n_scheda=41480
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [296/1000] n_scheda=41481
# [297/1000] n_scheda=41482
# [298/1000] n_scheda=41483
# [299/1000] n_scheda=41484
# [300/1000] n_scheda=41485
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [301/1000] n_scheda=41486
# [302/1000] n_scheda=41487
# [303/1000] n_scheda=41488
# [304/1000] n_scheda=41489
# [305/1000] n_scheda=41490
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [306/1000] n_scheda=41491
# [307/1000] n_scheda=41492
# [308/1000] n_scheda=41493
# [309/1000] n_scheda=41494
# [310/1000] n_scheda=41495
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [311/1000] n_scheda=41496
# [312/1000] n_scheda=41497
# [313/1000] n_scheda=41498
# [314/1000] n_scheda=41499
# [315/1000] n_scheda=41500
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [316/1000] n_scheda=41501
# [317/1000] n_scheda=41502
# [318/1000] n_scheda=41503
# [319/1000] n_scheda=41504
# [320/1000] n_scheda=41505
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [321/1000] n_scheda=41506
# [322/1000] n_scheda=41507
# [323/1000] n_scheda=41508
# [324/1000] n_scheda=41509
# [325/1000] n_scheda=41510
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [326/1000] n_scheda=41511
# [327/1000] n_scheda=41512
# [328/1000] n_scheda=41513
# [329/1000] n_scheda=41514
# [330/1000] n_scheda=41515
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [331/1000] n_scheda=41516
# [332/1000] n_scheda=41517
# [333/1000] n_scheda=41518
# [334/1000] n_scheda=41519
# [335/1000] n_scheda=41520
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [336/1000] n_scheda=41521
# [337/1000] n_scheda=41522
# [338/1000] n_scheda=41523
# [339/1000] n_scheda=41524
# [340/1000] n_scheda=41525
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [341/1000] n_scheda=41526
# [342/1000] n_scheda=41527
# [343/1000] n_scheda=41528
# [344/1000] n_scheda=41529
# [345/1000] n_scheda=41530
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [346/1000] n_scheda=41531
# [347/1000] n_scheda=41532
# [348/1000] n_scheda=41533
# [349/1000] n_scheda=41534
# [350/1000] n_scheda=41535
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [351/1000] n_scheda=41536
# [352/1000] n_scheda=41537
# [353/1000] n_scheda=41538
# [354/1000] n_scheda=41539
# [355/1000] n_scheda=41540
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [356/1000] n_scheda=41541
# [357/1000] n_scheda=41542
# [358/1000] n_scheda=41543
# [359/1000] n_scheda=41544
# [360/1000] n_scheda=41545
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [361/1000] n_scheda=41546
# [362/1000] n_scheda=41547
# [363/1000] n_scheda=41548
# [364/1000] n_scheda=41549
# [365/1000] n_scheda=41550
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [366/1000] n_scheda=41551
# [367/1000] n_scheda=41552
# [368/1000] n_scheda=41553
# [369/1000] n_scheda=41554
# [370/1000] n_scheda=41555
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [371/1000] n_scheda=41556
# [372/1000] n_scheda=41557
# [373/1000] n_scheda=41558
# [374/1000] n_scheda=41559
# [375/1000] n_scheda=41560
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [376/1000] n_scheda=41561
# [377/1000] n_scheda=41562
# [378/1000] n_scheda=41563
# [379/1000] n_scheda=41564
# [380/1000] n_scheda=41565
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [381/1000] n_scheda=41566
# [382/1000] n_scheda=41567
# [383/1000] n_scheda=41568
# [384/1000] n_scheda=41569
# [385/1000] n_scheda=41570
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [386/1000] n_scheda=41571
# [387/1000] n_scheda=41572
# [388/1000] n_scheda=41573
# [389/1000] n_scheda=41574
# [390/1000] n_scheda=41575
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [391/1000] n_scheda=41576
# [392/1000] n_scheda=41577
# [393/1000] n_scheda=41578
# [394/1000] n_scheda=41579
# [395/1000] n_scheda=41580
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [396/1000] n_scheda=41581
# [397/1000] n_scheda=41582
# [398/1000] n_scheda=41583
# [399/1000] n_scheda=41584
# [400/1000] n_scheda=41585
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [401/1000] n_scheda=41586
# [402/1000] n_scheda=41587
# [403/1000] n_scheda=41588
# [404/1000] n_scheda=41589
# [405/1000] n_scheda=41590
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [406/1000] n_scheda=41591
# [407/1000] n_scheda=41592
# [408/1000] n_scheda=41593
# [409/1000] n_scheda=41594
# [410/1000] n_scheda=41595
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [411/1000] n_scheda=41596
# [412/1000] n_scheda=41597
# [413/1000] n_scheda=41598
# [414/1000] n_scheda=41599
# [415/1000] n_scheda=41600
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [416/1000] n_scheda=41601
# [417/1000] n_scheda=41602
# [418/1000] n_scheda=41603
# [419/1000] n_scheda=41604
# [420/1000] n_scheda=41605
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [421/1000] n_scheda=41606
# [422/1000] n_scheda=41607
# [423/1000] n_scheda=41608
# [424/1000] n_scheda=41609
# [425/1000] n_scheda=41610
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [426/1000] n_scheda=41611
# [427/1000] n_scheda=41612
# [428/1000] n_scheda=41613
# [429/1000] n_scheda=41614
# [430/1000] n_scheda=41615
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [431/1000] n_scheda=41616
# [432/1000] n_scheda=41617
# [433/1000] n_scheda=41618
# [434/1000] n_scheda=41619
# [435/1000] n_scheda=41620
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [436/1000] n_scheda=41621
# [437/1000] n_scheda=41622
# [438/1000] n_scheda=41623
# [439/1000] n_scheda=41624
# [440/1000] n_scheda=41625
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [441/1000] n_scheda=41626
# [442/1000] n_scheda=41627
# [443/1000] n_scheda=41628
# [444/1000] n_scheda=41629
# [445/1000] n_scheda=41630
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [446/1000] n_scheda=41631
# [447/1000] n_scheda=41632
# [448/1000] n_scheda=41633
# [449/1000] n_scheda=41634
# [450/1000] n_scheda=41635
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [451/1000] n_scheda=41636
# [452/1000] n_scheda=41637
# [453/1000] n_scheda=41638
# [454/1000] n_scheda=41639
# [455/1000] n_scheda=41640
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [456/1000] n_scheda=41641
# [457/1000] n_scheda=41642
# [458/1000] n_scheda=41643
# [459/1000] n_scheda=41644
# [460/1000] n_scheda=41645
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [461/1000] n_scheda=41646
# [462/1000] n_scheda=41647
# [463/1000] n_scheda=41648
# [464/1000] n_scheda=41649
# [465/1000] n_scheda=41650
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [466/1000] n_scheda=41651
# [467/1000] n_scheda=41652
# [468/1000] n_scheda=41653
# [469/1000] n_scheda=41654
# [470/1000] n_scheda=41655
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [471/1000] n_scheda=41656
# [472/1000] n_scheda=41657
# [473/1000] n_scheda=41658
# [474/1000] n_scheda=41659
# [475/1000] n_scheda=41660
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [476/1000] n_scheda=41661
# [477/1000] n_scheda=41662
# [478/1000] n_scheda=41663
# [479/1000] n_scheda=41664
# [480/1000] n_scheda=41665
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [481/1000] n_scheda=41666
# [482/1000] n_scheda=41667
# [483/1000] n_scheda=41668
# [484/1000] n_scheda=41669
# [485/1000] n_scheda=41670
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [486/1000] n_scheda=41671
# [487/1000] n_scheda=41672
# [488/1000] n_scheda=41673
# [489/1000] n_scheda=41674
# [490/1000] n_scheda=41675
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [491/1000] n_scheda=41676
# [492/1000] n_scheda=41677
# [493/1000] n_scheda=41678
# [494/1000] n_scheda=41679
# [495/1000] n_scheda=41680
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [496/1000] n_scheda=41681
# [497/1000] n_scheda=41682
# [498/1000] n_scheda=41683
# [499/1000] n_scheda=41684
# [500/1000] n_scheda=41685
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [501/1000] n_scheda=41686
# [502/1000] n_scheda=41687
# [503/1000] n_scheda=41688
# [504/1000] n_scheda=41689
# [505/1000] n_scheda=41690
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [506/1000] n_scheda=41691
# [507/1000] n_scheda=41692
# [508/1000] n_scheda=41693
# [509/1000] n_scheda=41694
# [510/1000] n_scheda=41695
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [511/1000] n_scheda=41696
# [512/1000] n_scheda=41697
# [513/1000] n_scheda=41698
# [514/1000] n_scheda=41699
# [515/1000] n_scheda=41700
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [516/1000] n_scheda=41701
# [517/1000] n_scheda=41702
# [518/1000] n_scheda=41703
# [519/1000] n_scheda=41704
# [520/1000] n_scheda=41705
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [521/1000] n_scheda=41706
# [522/1000] n_scheda=41707
# [523/1000] n_scheda=41708
# [524/1000] n_scheda=41709
# [525/1000] n_scheda=41710
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [526/1000] n_scheda=41711
# [527/1000] n_scheda=41712
# [528/1000] n_scheda=41713
# [529/1000] n_scheda=41714
# [530/1000] n_scheda=41715
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [531/1000] n_scheda=41716
# [532/1000] n_scheda=41717
# [533/1000] n_scheda=41718
# [534/1000] n_scheda=41719
# [535/1000] n_scheda=41720
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [536/1000] n_scheda=41721
# [537/1000] n_scheda=41722
# [538/1000] n_scheda=41723
# [539/1000] n_scheda=41724
# [540/1000] n_scheda=41725
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [541/1000] n_scheda=41726
# [542/1000] n_scheda=41727
# [543/1000] n_scheda=41728
# [544/1000] n_scheda=41729
# [545/1000] n_scheda=41730
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [546/1000] n_scheda=41731
# [547/1000] n_scheda=41732
# [548/1000] n_scheda=41733
# [549/1000] n_scheda=41734
# [550/1000] n_scheda=41735
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [551/1000] n_scheda=41736
# [552/1000] n_scheda=41737
# [553/1000] n_scheda=41738
# [554/1000] n_scheda=41739
# [555/1000] n_scheda=41740
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [556/1000] n_scheda=41741
# [557/1000] n_scheda=41742
# [558/1000] n_scheda=41743
# [559/1000] n_scheda=41744
# [560/1000] n_scheda=41745
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [561/1000] n_scheda=41746
# [562/1000] n_scheda=41747
# [563/1000] n_scheda=41748
# [564/1000] n_scheda=41749
# [565/1000] n_scheda=41750
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [566/1000] n_scheda=41751
# [567/1000] n_scheda=41752
# [568/1000] n_scheda=41753
# [569/1000] n_scheda=41754
# [570/1000] n_scheda=41755
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [571/1000] n_scheda=41756
# [572/1000] n_scheda=41757
# [573/1000] n_scheda=41758
# [574/1000] n_scheda=41759
# [575/1000] n_scheda=41760
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [576/1000] n_scheda=41761
# [577/1000] n_scheda=41762
# [578/1000] n_scheda=41763
# [579/1000] n_scheda=41764
# [580/1000] n_scheda=41765
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [581/1000] n_scheda=41766
# [582/1000] n_scheda=41767
# [583/1000] n_scheda=41768
# [584/1000] n_scheda=41769
# [585/1000] n_scheda=41770
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [586/1000] n_scheda=41771
# [587/1000] n_scheda=41772
# [588/1000] n_scheda=41773
# [589/1000] n_scheda=41774
# [590/1000] n_scheda=41775
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [591/1000] n_scheda=41776
# [592/1000] n_scheda=41777
# [593/1000] n_scheda=41778
# [594/1000] n_scheda=41779
# [595/1000] n_scheda=41780
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [596/1000] n_scheda=41781
# [597/1000] n_scheda=41782
# [598/1000] n_scheda=41783
# [599/1000] n_scheda=41784
# [600/1000] n_scheda=41785
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [601/1000] n_scheda=41786
# [602/1000] n_scheda=41787
# [603/1000] n_scheda=41788
# [604/1000] n_scheda=41789
# [605/1000] n_scheda=41790
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [606/1000] n_scheda=41791
# [607/1000] n_scheda=41792
# [608/1000] n_scheda=41793
# [609/1000] n_scheda=41794
# [610/1000] n_scheda=41795
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [611/1000] n_scheda=41796
# [612/1000] n_scheda=41797
# [613/1000] n_scheda=41798
# [614/1000] n_scheda=41799
# [615/1000] n_scheda=41800
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [616/1000] n_scheda=41801
# [617/1000] n_scheda=41802
# [618/1000] n_scheda=41803
# [619/1000] n_scheda=41804
# [620/1000] n_scheda=41805
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [621/1000] n_scheda=41806
# [622/1000] n_scheda=41807
# [623/1000] n_scheda=41808
# [624/1000] n_scheda=41809
# [625/1000] n_scheda=41810
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [626/1000] n_scheda=41811
# [627/1000] n_scheda=41812
# [628/1000] n_scheda=41813
# [629/1000] n_scheda=41814
# [630/1000] n_scheda=41815
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [631/1000] n_scheda=41816
# [632/1000] n_scheda=41817
# [633/1000] n_scheda=41818
# [634/1000] n_scheda=41819
# [635/1000] n_scheda=41820
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [636/1000] n_scheda=41821
# [637/1000] n_scheda=41822
# [638/1000] n_scheda=41823
# [639/1000] n_scheda=41824
# [640/1000] n_scheda=41825
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [641/1000] n_scheda=41826
# [642/1000] n_scheda=41827
# [643/1000] n_scheda=41828
# [644/1000] n_scheda=41829
# [645/1000] n_scheda=41830
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [646/1000] n_scheda=41831
# [647/1000] n_scheda=41832
# [648/1000] n_scheda=41833
# [649/1000] n_scheda=41834
# [650/1000] n_scheda=41835
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [651/1000] n_scheda=41836
# [652/1000] n_scheda=41837
# [653/1000] n_scheda=41838
# [654/1000] n_scheda=41839
# [655/1000] n_scheda=41840
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [656/1000] n_scheda=41841
# [657/1000] n_scheda=41842
# [658/1000] n_scheda=41843
# [659/1000] n_scheda=41844
# [660/1000] n_scheda=41845
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [661/1000] n_scheda=41846
# [662/1000] n_scheda=41847
# [663/1000] n_scheda=41848
# [664/1000] n_scheda=41849
# [665/1000] n_scheda=41850
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [666/1000] n_scheda=41851
# [667/1000] n_scheda=41852
# [668/1000] n_scheda=41853
# [669/1000] n_scheda=41854
# [670/1000] n_scheda=41855
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [671/1000] n_scheda=41856
# [672/1000] n_scheda=41857
# [673/1000] n_scheda=41858
# [674/1000] n_scheda=41859
# [675/1000] n_scheda=41860
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [676/1000] n_scheda=41861
# [677/1000] n_scheda=41862
# [678/1000] n_scheda=41863
# [679/1000] n_scheda=41864
# [680/1000] n_scheda=41865
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [681/1000] n_scheda=41866
# [682/1000] n_scheda=41867
# [683/1000] n_scheda=41868
# [684/1000] n_scheda=41869
# [685/1000] n_scheda=41870
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [686/1000] n_scheda=41871
# [687/1000] n_scheda=41872
# [688/1000] n_scheda=41873
# [689/1000] n_scheda=41874
# [690/1000] n_scheda=41875
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [691/1000] n_scheda=41876
# [692/1000] n_scheda=41877
# [693/1000] n_scheda=41878
# [694/1000] n_scheda=41879
# [695/1000] n_scheda=41880
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [696/1000] n_scheda=41881
# [697/1000] n_scheda=41882
# [698/1000] n_scheda=41883
# [699/1000] n_scheda=41884
# [700/1000] n_scheda=41885
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [701/1000] n_scheda=41886
# [702/1000] n_scheda=41887
# [703/1000] n_scheda=41888
# [704/1000] n_scheda=41889
# [705/1000] n_scheda=41890
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [706/1000] n_scheda=41891
# [707/1000] n_scheda=41892
# [708/1000] n_scheda=41893
# [709/1000] n_scheda=41894
# [710/1000] n_scheda=41895
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [711/1000] n_scheda=41896
# [712/1000] n_scheda=41897
# [713/1000] n_scheda=41898
# [714/1000] n_scheda=41899
# [715/1000] n_scheda=41900
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [716/1000] n_scheda=41901
# [717/1000] n_scheda=41902
# [718/1000] n_scheda=41903
# [719/1000] n_scheda=41904
# [720/1000] n_scheda=41905
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [721/1000] n_scheda=41906
# [722/1000] n_scheda=41907
# [723/1000] n_scheda=41908
# [724/1000] n_scheda=41909
# [725/1000] n_scheda=41910
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [726/1000] n_scheda=41911
# [727/1000] n_scheda=41912
# [728/1000] n_scheda=41913
# [729/1000] n_scheda=41914
# [730/1000] n_scheda=41915
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [731/1000] n_scheda=41916
# [732/1000] n_scheda=41917
# [733/1000] n_scheda=41918
# [734/1000] n_scheda=41919
# [735/1000] n_scheda=41920
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [736/1000] n_scheda=41921
# [737/1000] n_scheda=41922
# [738/1000] n_scheda=41923
# [739/1000] n_scheda=41924
# [740/1000] n_scheda=41925
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [741/1000] n_scheda=41926
# [742/1000] n_scheda=41927
# [743/1000] n_scheda=41928
# [744/1000] n_scheda=41929
# [745/1000] n_scheda=41930
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [746/1000] n_scheda=41931
# [747/1000] n_scheda=41932
# [748/1000] n_scheda=41933
# [749/1000] n_scheda=41934
# [750/1000] n_scheda=41935
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [751/1000] n_scheda=41936
# [752/1000] n_scheda=41937
# [753/1000] n_scheda=41938
# [754/1000] n_scheda=41939
# [755/1000] n_scheda=41940
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [756/1000] n_scheda=41941
# [757/1000] n_scheda=41942
# [758/1000] n_scheda=41943
# [759/1000] n_scheda=41944
# [760/1000] n_scheda=41945
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [761/1000] n_scheda=41946
# [762/1000] n_scheda=41947
# [763/1000] n_scheda=41948
# [764/1000] n_scheda=41949
# [765/1000] n_scheda=41950
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [766/1000] n_scheda=41951
# [767/1000] n_scheda=41952
# [768/1000] n_scheda=41953
# [769/1000] n_scheda=41954
# [770/1000] n_scheda=41955
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [771/1000] n_scheda=41956
# [772/1000] n_scheda=41957
# [773/1000] n_scheda=41958
# [774/1000] n_scheda=41959
# [775/1000] n_scheda=41960
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [776/1000] n_scheda=41961
# [777/1000] n_scheda=41962
# [778/1000] n_scheda=41963
# [779/1000] n_scheda=41964
# [780/1000] n_scheda=41965
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [781/1000] n_scheda=41966
# [782/1000] n_scheda=41967
# [783/1000] n_scheda=41968
# [784/1000] n_scheda=41969
# [785/1000] n_scheda=41970
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [786/1000] n_scheda=41971
# [787/1000] n_scheda=41972
# [788/1000] n_scheda=41973
# [789/1000] n_scheda=41974
# [790/1000] n_scheda=41975
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [791/1000] n_scheda=41976
# [792/1000] n_scheda=41977
# [793/1000] n_scheda=41978
# [794/1000] n_scheda=41979
# [795/1000] n_scheda=41980
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [796/1000] n_scheda=41981
# [797/1000] n_scheda=41982
# [798/1000] n_scheda=41983
# [799/1000] n_scheda=41984
# [800/1000] n_scheda=41985
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [801/1000] n_scheda=41986
# [802/1000] n_scheda=41987
# [803/1000] n_scheda=41988
# [804/1000] n_scheda=41989
# [805/1000] n_scheda=41990
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [806/1000] n_scheda=41991
# [807/1000] n_scheda=41992
# [808/1000] n_scheda=41993
# [809/1000] n_scheda=41994
# [810/1000] n_scheda=41995
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [811/1000] n_scheda=41996
# [812/1000] n_scheda=41997
# [813/1000] n_scheda=41998
# [814/1000] n_scheda=41999
# [815/1000] n_scheda=42000
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [816/1000] n_scheda=42001
# [817/1000] n_scheda=42002
# [818/1000] n_scheda=42003
# [819/1000] n_scheda=42004
# [820/1000] n_scheda=42005
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [821/1000] n_scheda=42006
# [822/1000] n_scheda=42007
# [823/1000] n_scheda=42008
# [824/1000] n_scheda=42009
# [825/1000] n_scheda=42010
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [826/1000] n_scheda=42011
# [827/1000] n_scheda=42012
# [828/1000] n_scheda=42013
# [829/1000] n_scheda=42014
# [830/1000] n_scheda=42015
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [831/1000] n_scheda=42016
# [832/1000] n_scheda=42017
# [833/1000] n_scheda=42018
# [834/1000] n_scheda=42019
# [835/1000] n_scheda=42020
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [836/1000] n_scheda=42021
# [837/1000] n_scheda=42022
# [838/1000] n_scheda=42023
# [839/1000] n_scheda=42024
# [840/1000] n_scheda=42025
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [841/1000] n_scheda=42026
# [842/1000] n_scheda=42027
# [843/1000] n_scheda=42028
# [844/1000] n_scheda=42029
# [845/1000] n_scheda=42030
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [846/1000] n_scheda=42031
# [847/1000] n_scheda=42032
# [848/1000] n_scheda=42033
# [849/1000] n_scheda=42034
# [850/1000] n_scheda=42035
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [851/1000] n_scheda=42036
# [852/1000] n_scheda=42037
# [853/1000] n_scheda=42038
# [854/1000] n_scheda=42039
# [855/1000] n_scheda=42040
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [856/1000] n_scheda=42041
# [857/1000] n_scheda=42042
# [858/1000] n_scheda=42043
# [859/1000] n_scheda=42044
# [860/1000] n_scheda=42045
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [861/1000] n_scheda=42046
# [862/1000] n_scheda=42047
# [863/1000] n_scheda=42048
# [864/1000] n_scheda=42049
# [865/1000] n_scheda=42050
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [866/1000] n_scheda=42051
# [867/1000] n_scheda=42052
# [868/1000] n_scheda=42053
# [869/1000] n_scheda=42054
# [870/1000] n_scheda=42055
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [871/1000] n_scheda=42056
# [872/1000] n_scheda=42057
# [873/1000] n_scheda=42058
# [874/1000] n_scheda=42059
# [875/1000] n_scheda=42060
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [876/1000] n_scheda=42061
# [877/1000] n_scheda=42062
# [878/1000] n_scheda=42063
# [879/1000] n_scheda=42064
# [880/1000] n_scheda=42065
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [881/1000] n_scheda=42066
# [882/1000] n_scheda=42067
# [883/1000] n_scheda=42068
# [884/1000] n_scheda=42069
# [885/1000] n_scheda=42070
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [886/1000] n_scheda=42071
# [887/1000] n_scheda=42072
# [888/1000] n_scheda=42073
# [889/1000] n_scheda=42074
# [890/1000] n_scheda=42075
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [891/1000] n_scheda=42076
# [892/1000] n_scheda=42077
# [893/1000] n_scheda=42078
# [894/1000] n_scheda=42079
# [895/1000] n_scheda=42080
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [896/1000] n_scheda=42081
# [897/1000] n_scheda=42082
# [898/1000] n_scheda=42083
# [899/1000] n_scheda=42084
# [900/1000] n_scheda=42085
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [901/1000] n_scheda=42086
# [902/1000] n_scheda=42087
# [903/1000] n_scheda=42088
# [904/1000] n_scheda=42089
# [905/1000] n_scheda=42090
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [906/1000] n_scheda=42091
# [907/1000] n_scheda=42092
# [908/1000] n_scheda=42093
# [909/1000] n_scheda=42094
# [910/1000] n_scheda=42095
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [911/1000] n_scheda=42096
# [912/1000] n_scheda=42097
# [913/1000] n_scheda=42098
# [914/1000] n_scheda=42099
# [915/1000] n_scheda=42100
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [916/1000] n_scheda=42101
# [917/1000] n_scheda=42102
# [918/1000] n_scheda=42103
# [919/1000] n_scheda=42104
# [920/1000] n_scheda=42105
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [921/1000] n_scheda=42106
# [922/1000] n_scheda=42107
# [923/1000] n_scheda=42108
# [924/1000] n_scheda=42109
# [925/1000] n_scheda=42110
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [926/1000] n_scheda=42111
# [927/1000] n_scheda=42112
# [928/1000] n_scheda=42113
# [929/1000] n_scheda=42114
# [930/1000] n_scheda=42115
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [931/1000] n_scheda=42116
# [932/1000] n_scheda=42117
# [933/1000] n_scheda=42118
# [934/1000] n_scheda=42119
# [935/1000] n_scheda=42120
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [936/1000] n_scheda=42121
# [937/1000] n_scheda=42122
# [938/1000] n_scheda=42123
# [939/1000] n_scheda=42124
# [940/1000] n_scheda=42125
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [941/1000] n_scheda=42126
# [942/1000] n_scheda=42127
# [943/1000] n_scheda=42128
# [944/1000] n_scheda=42129
# [945/1000] n_scheda=42130
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [946/1000] n_scheda=42131
# [947/1000] n_scheda=42132
# [948/1000] n_scheda=42133
# [949/1000] n_scheda=42134
# [950/1000] n_scheda=42135
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [951/1000] n_scheda=42136
# [952/1000] n_scheda=42137
# [953/1000] n_scheda=42138
# [954/1000] n_scheda=42139
# [955/1000] n_scheda=42140
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [956/1000] n_scheda=42141
# [957/1000] n_scheda=42142
# [958/1000] n_scheda=42143
# [959/1000] n_scheda=42144
# [960/1000] n_scheda=42145
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [961/1000] n_scheda=42146
# [962/1000] n_scheda=42147
# [963/1000] n_scheda=42148
# [964/1000] n_scheda=42149
# [965/1000] n_scheda=42150
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [966/1000] n_scheda=42151
# [967/1000] n_scheda=42152
# [968/1000] n_scheda=42153
# [969/1000] n_scheda=42154
# [970/1000] n_scheda=42155
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [971/1000] n_scheda=42156
# [972/1000] n_scheda=42157
# [973/1000] n_scheda=42158
# [974/1000] n_scheda=42159
# [975/1000] n_scheda=42160
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [976/1000] n_scheda=42161
# [977/1000] n_scheda=42162
# [978/1000] n_scheda=42163
# [979/1000] n_scheda=42164
# [980/1000] n_scheda=42165
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [981/1000] n_scheda=42166
# [982/1000] n_scheda=42167
# [983/1000] n_scheda=42168
# [984/1000] n_scheda=42169
# [985/1000] n_scheda=42170
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [986/1000] n_scheda=42171
# [987/1000] n_scheda=42172
# [988/1000] n_scheda=42173
# [989/1000] n_scheda=42174
# [990/1000] n_scheda=42175
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [991/1000] n_scheda=42176
# [992/1000] n_scheda=42177
# [993/1000] n_scheda=42178
# [994/1000] n_scheda=42179
# [995/1000] n_scheda=42180
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# [996/1000] n_scheda=42181
# [997/1000] n_scheda=42182
# [998/1000] n_scheda=42183
# [999/1000] n_scheda=42184
# [1000/1000] n_scheda=42185
# Checkpoint scritto: biblio_longform_all_records_enriched.csv
# Completato. Output: biblio_longform_all_records_enriched.csv

# %%
#da longform a wide (con gestione duplicati)

import pandas as pd

ENRICHED_LONGFORM = "biblio_longform_all_records_enriched.csv"
OUTPUT_WIDE = "biblio_wide_records_enriched.csv"

df_long = pd.read_csv(ENRICHED_LONGFORM)
df_long["valore"] = df_long["valore"].fillna("").astype(str)

# Evita collisione: il campo "n_scheda" (in colonna 'campo') viene rinominato
df_long = df_long.copy()
df_long.loc[df_long["campo"] == "n_scheda", "campo"] = "n_scheda_field"

# Aggregazione (se per lo stesso campo ci sono più valori, li concatena)
agg = (df_long
       .groupby(["n_scheda", "campo"])["valore"]
       .agg(lambda s: " | ".join([v.strip() for v in s if isinstance(v, str) and v.strip()]))
       .reset_index()
      )

# Pivot wide
df_wide = agg.pivot(index="n_scheda", columns="campo", values="valore").reset_index()

# Riordino colonne (opzionale)
front = ["n_scheda", "titolo", "autore", "data_pub", "editore",
         "ext_source", "ext_match_score", "ext_url", "ext_identifiers", "n_scheda_field"]
cols = [c for c in front if c in df_wide.columns] + [c for c in df_wide.columns if c not in front]
df_wide = df_wide[cols]

df_wide.to_csv(OUTPUT_WIDE, index=False)
print("Creato:", OUTPUT_WIDE, "| righe:", len(df_wide), "| colonne:", len(df_wide.columns))
# Out:
# Creato: biblio_wide_records_enriched.csv | righe: 1000 | colonne: 29
